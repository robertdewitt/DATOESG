# %% [markdown]
# #### **Machine Learning and Data Science Research Project - Milestone 2**
#
# **Project:** Reinforcement Learning for Optimal Execution
#
# **Author:** Robert de Witt (CID: 02541719)
#
# **Research Goals**
#
# This project investigates whether reinforcement learning–driven execution policies can reduce slippage relative to mid-price benchmarks. The primary goal is to explore and apply reinforcement learning techniques to find a superior performing trading strategy to minimize slippage to the mid-point arrival price $p_0$ when the order starts.
#
# Formally defined as:
#
# * Slippage per order $i$
#
# $$
#   s_i = \text{side}_i \cdot p_{0,i} - \bar p_{\mathrm{order},i},
#   \quad
#   p_{0,i} = \frac{p^{\mathrm{bid}}_i[t_0] + p^{\mathrm{ask}}_i[t_0]}{2}.
# $$
#
# * Where $side_i = 1$ if a buy order, $side_i = -1$ if a sell order and $\bar{p}_{{order},i} = \sum^{i<=H}_{i=1} \frac{p_i * q_i}{Q_i}$, and $q_i$ is the filled quantity per child order, $Q_i$ is the executed total executed quantity.
#
# * The goal is to minimize notionally weighted slippage for all executed orders:
#
# $$  \min \bar s_{\mathrm{wtd}}
#   \;=\;\sum_{i=1}^n s_i \,\bigl(\bar p_{\mathrm{order},i}\,Q_i\bigr).
# $$
#
# * We also create a hypothetical best execution price where we rank the prices
#
# **Overview of Gym workflow**
#
# **Goals**
#
# We will try a number of agents based on multiple papers, as well as some novel approaches to reinforcement learning such as Quality Diversity [1-3] and MAP-Elites approaches [4-6]. All agents will be tuned for the same purposes . In order to achieve this, a realistic gym (back-testing) environment must be established. The gym will accept train, test and optional validation sets of random orders across a series of dates and stocks, each with different horizons and percentages of average daily volumes. In the final project, we will also ensure these orders are diversified across a number of market regimes to ensure robustness when the agents being trained and tested. For each of the orders, we will train, test and validate each of the agents. We will compare all agents performance across a large number market segments and benchmarks including arrival price, VWAP, completion rate, opportunity cost, variation of trade rates, hypothetical best price, etc. to confirm robustness of the best agent.
#
# Detailed explanations are in the document covering:
#
# * Order Generation
# * RL Environment
# * Trading Sumulation
# * Agent being tested
# * Evaluation of Agents

# %% [markdown]
# TO-DOs:
# * Impact is way too small - what happened? - parameters make sense?
# * explain project set up - clean up text
# * add volatility, stock return to each order
# * TODO: plot order statistics - size, volatility, interval returns
# * explain reinforcement learning states, actions & gym set up
# * explain agent testing framework and set up
# * TODO: summarize sample order results - add action percent versus accumulated impact, add reward
# * run through summary statistics
# * Why does the reward change at the end of the time horizon?
# * comment all code appropriately
# * print to PDF
# * Submit all cod
# * TODO: create a new agent and run across different regimes to see how they perform#

# %%
from mkt_data_yfinance import MarketDataLoader as mdl
import render_plots
import pandas as pd
from optimal_execution_env import MultiOrderExecutionEnv
from order_generator import OrderGenerator
from notebook_logging_setup import quick_setup
from gymnasium.utils.env_checker import check_env
from stable_baselines3 import PPO
from gymnasium.wrappers import TimeLimit
import torch
from stable_baselines3.common.vec_env import SubprocVecEnv
import numpy as np

quick_setup(debug=False)
# Out:
# Logging configured at INFO level

# %%
max_trading_rate = 0.8
max_order_size_in_adv_pct = 0.1
tickers = ['AAPL','MSFT','GOOGL','AMZN','TSLA','NVDA','JPM','V','JNJ','DIS']
md = mdl()
stock_df_list = md.load_data(tickers)
stock_df_list = md.pre_process_data(stock_df_list)
# Out:
# YF.download() has changed argument auto_adjust default to True
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %%
# print first 3 rows of each stock dataframe
#for stock in stock_df_list:
#    print(stock_df_list[stock].head(-3))
# Create the environment

# %%
# print first 3 rows of each stock dataframe
#for stock in stock_df_list:
#    print(stock_df_list[stock].head(-3))
# Create the environment

# %% [markdown]
# **Order Generation**
#
# The order generation process creates a set of trading orders with the following characteristics:
# 1.  For each order, a random stock is selected from the available universe, and its Average Daily Volume (ADV) is calculated as the mean of daily trading volumes.
# 2. The order size is determined by sampling a random percentage of ADV between min_adv_pct and max_adv_pct, scaled by the time horizon (as a fraction of the trading day). This ensures that larger orders are spread over longer time periods.
# 3. The execution window is defined by randomly selecting a start time and a time horizon (in minutes) between min_time_horizon and max_time_horizon, with the end time being start_time + time_horizon.
# 4. Each order is assigned a random side (buy/sell) and its quantity is rounded to the nearest integer, with safeguards to prevent zero-sized orders. The resulting orders are then used to train or evaluate the execution strategy in the reinforcement learning environment.

# %%
train_orders_df = OrderGenerator(stock_df_list=stock_df_list, market_data=md, debug=False, max_adv_pct=max_order_size_in_adv_pct, num_orders=50000).get_orders()
test_orders_df = OrderGenerator(stock_df_list=stock_df_list, market_data=md, debug=False, max_adv_pct=max_order_size_in_adv_pct, num_orders=20000).get_orders()
# Out:
# min_adv_percent: 0.0001, max_adv_percent: 0.1, Percentage of day for time horizon: [0.94102564 0.01025641 0.04102564 ... 0.2        0.07179487 0.29230769]
# min_adv_percent: 0.0001, max_adv_percent: 0.1, Percentage of day for time horizon: [0.65897436 0.15641026 0.8974359  ... 0.13589744 0.57948718 0.99230769]

# %%
# print orders dataframe in single line per order
render_plots.display_order_info(train_orders_df, name='Train', num_orders=3)
render_plots.display_order_info(test_orders_df, name='Test', num_orders=3)
# Out:
# 3 Train Orders:
# ========================================
# Train (1): ticker: AAPL order_qty: 2882482 adv_pct: 6.4433% adv: 44,735,904 start_time: 8 end_time: 375 time_horizon: 367 side: sell
# Train (2): ticker: AAPL order_qty: 18175 adv_pct: 0.0406% adv: 44,735,904 start_time: 189 end_time: 193 time_horizon: 4 side: sell
# Train (3): ticker: JPM order_qty: 15283 adv_pct: 0.2566% adv: 5,956,588 start_time: 234 end_time: 250 time_horizon: 16 side: buy
# ========================================
# 3 Test Orders:
# ========================================
# Test (1): ticker: JPM order_qty: 343767 adv_pct: 5.7712% adv: 5,956,588 start_time: 20 end_time: 277 time_horizon: 257 side: buy
# Test (2): ticker: JPM order_qty: 80955 adv_pct: 1.3591% adv: 5,956,588 start_time: 172 end_time: 233 time_horizon: 61 side: buy
# Test (3): ticker: V order_qty: 288283 adv_pct: 5.9210% adv: 4,868,828 start_time: 5 end_time: 355 time_horizon: 350 side: buy
# ========================================

# %% [markdown]
# **RL Environment**
#
# **Simulation of Trading**
#
# In order to realistically simulate market behaviour, each trade needs to create impact, and successive trades must propagate impact to the next order. Rather than consider the nuance of trade by trade, limit and market orders and order books which require many assumptions and complex limit order book simulators, we focus on minutely percentage of volume trading. This allows to focus on building an optimal scheduling algorithm and remoces the granular needs of impact estimations.
#
# For minutely impact level impact estimations have utilized the transient impact model 2 from Bouchaud's book Trades, Quotes and Prices [7] which is set at default values for this update and assumes the 1 minute trade impact follows square root.  We account for gaps between 1 minute trade intervals allowing for more accurate decay. In the final report, we will include a well calibrated version of this model based on the trades observed via Bank of America's trade data.
#
#
# **Linear Transient‐Impact (Propagator) Model [7]**
# $$
# r_t \;=\;\sum_{t'<t} G(t - t')\,\epsilon_{t'} \;+\;\eta_t,
# $$
# where $r_t = P_t - P_{t-1}$ is the mid-price return, $\epsilon_{t'}\!=\pm1$ the sign of the trade at time $t'$, $G(\tau)$ the propagator kernel, and $\eta_t$ an uncorrelated noise term.
#
# In our case we do allow for non-uniformity of time steps between trades so we modify to consider the $t_{\Delta}$:
#
# $$
# \lambda(\Delta t)
# \;=\;
# \exp\!\Bigl(-\frac{\Delta t}{\tau}\Bigr),
# \quad
# \Delta I_t
# \;=\;
# Y\,\sigma\,\sqrt{\frac{q_t}{V}},
# $$
#
# $$
# I_t
# \;=\;
# \lambda(\Delta t)\,I_{t-1}
# \;+\;
# \Delta I_t,
# $$
#
# $$
# p_t^{\mathrm{fill}}
# \;=\;
# p_t^{\mathrm{vwap}}
# \bigl(1 \;+\; s\,I_t\bigr).
# $$

# %%
# gwnerat the execution environments for training
train_execution_env = MultiOrderExecutionEnv(stock_df_list=stock_df_list, orders_df=train_orders_df, impact_coef=1, num_envs=1, decay_rate=5, window_size=1, min_rate=0, max_rate=max_trading_rate)
max_horizon = int(train_orders_df["time_horizon"].max())
print(f"Maximum time horizon for orders: {max_horizon} minutes")
train_env = TimeLimit(train_execution_env, max_episode_steps=max_horizon)
check_env(train_env)

# gwnerat the execution environments for testing
test_execution_env = MultiOrderExecutionEnv(stock_df_list=stock_df_list, orders_df=test_orders_df, impact_coef=1, num_envs=1, decay_rate=5, window_size=1, min_rate=0, max_rate=max_trading_rate)
max_horizon = int(test_orders_df["time_horizon"].max())
print(f"Maximum time horizon for orders: {max_horizon} minutes")
test_env = TimeLimit(test_execution_env, max_episode_steps=max_horizon)
check_env(test_env)
# Out:
# 2025-06-15 17:57:25 - optimal_execution_env - INFO - Using device: mps
# Maximum time horizon for orders: 389 minutes
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/gymnasium/utils/env_checker.py:384: UserWarning: WARN: The environment (<TimeLimit<MultiOrderExecutionEnv instance>>) is different from the unwrapped version (<MultiOrderExecutionEnv instance>). This could effect the environment checker as the environment most likely has a wrapper applied to it. We recommend using the raw environment for `check_env` using `env.unwrapped`.
#   logger.warn(
# 2025-06-15 17:57:25 - optimal_execution_env - INFO - Using device: mps
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/gymnasium/utils/env_checker.py:434: UserWarning: WARN: Not able to test alternative render modes due to the environment not having a spec. Try instantiating the environment through `gymnasium.make`
#   logger.warn(
# Maximum time horizon for orders: 389 minutes

# %% [markdown]
# **Agents**

# %%
model = PPO("MlpPolicy", train_env, device="cpu", verbose=1, learning_rate=3e-4, 
            n_steps=512, batch_size=256, n_epochs=10,gamma=0.99, gae_lambda=0.95, clip_range=0.2,
            policy_kwargs=dict(net_arch=dict(pi=[256, 256], vf=[256, 256]), activation_fn=torch.nn.ReLU))
model.learn(total_timesteps=2000)
model.save("ppo_multiorder_exec")
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 32.8      |
# |    ep_rew_mean     | -1.34e+06 |
# | time/              |           |
# |    fps             | 67        |
# |    iterations      | 1         |
# |    time_elapsed    | 7         |
# |    total_timesteps | 512       |
# ----------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 37.7         |
# |    ep_rew_mean          | -9.07e+05    |
# | time/                   |              |
# |    fps                  | 66           |
# |    iterations           | 2            |
# |    time_elapsed         | 15           |
# |    total_timesteps      | 1024         |
# | train/                  |              |
# |    approx_kl            | 0.0010149021 |
# |    clip_fraction        | 0.00176      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.00369     |
# |    explained_variance   | -0.00244     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.74e+12     |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.00155     |
# |    value_loss           | 3.25e+12     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 35.6         |
# |    ep_rew_mean          | -1.64e+06    |
# | time/                   |              |
# |    fps                  | 66           |
# |    iterations           | 3            |
# |    time_elapsed         | 23           |
# |    total_timesteps      | 1536         |
# | train/                  |              |
# |    approx_kl            | 3.434252e-08 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0149      |
# |    explained_variance   | -0.102       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.3e+12      |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -2.03e-07    |
# |    value_loss           | 3.14e+12     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 32.7          |
# |    ep_rew_mean          | -1.47e+06     |
# | time/                   |               |
# |    fps                  | 64            |
# |    iterations           | 4             |
# |    time_elapsed         | 31            |
# |    total_timesteps      | 2048          |
# | train/                  |               |
# |    approx_kl            | 6.0535967e-09 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.00437      |
# |    explained_variance   | 0.0794        |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.34e+12      |
# |    n_updates            | 30            |
# |    policy_gradient_loss | -1.71e-06     |
# |    value_loss           | 5.62e+12      |
# -------------------------------------------

# %%
model = PPO.load("ppo_multiorder_exec")

train_orders = train_execution_env.execute_orders(model=model,num_episodes=10)
test_orders = test_execution_env.execute_orders(model=model,num_episodes=10)

# %%
orders_by_minute_df = pd.DataFrame(columns=['episode','current_step', 'order_idx', 'ticker', 'side', 'order_qty', 'adv_pct', 'start_time', 'end_time', 'time_horizon'])
print(f"Executed {len(test_orders)} orders:")
for episode in test_orders:
    for order in episode:
        orders_by_minute_df = pd.concat([orders_by_minute_df, pd.DataFrame([order])], ignore_index=True)
# Out:
# Executed 10 orders:
# /var/folders/mn/sstp0slh8xjckg0059bj70p80000gp/T/ipykernel_26071/3841225797.py:5: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   orders_by_minute_df = pd.concat([orders_by_minute_df, pd.DataFrame([order])], ignore_index=True)

# %%
pd.set_option('display.max_columns', None)
orders_by_minute_df[orders_by_minute_df['episode'] == 1]
# Out:
#     episode current_step order_idx ticker side order_qty   adv_pct start_time  \
# 224       1            0         1   NVDA  buy   9452974  0.059898         23
# 225       1            0         1   NVDA  buy   9452974  0.059898         23
# 226       1            1         1   NVDA  buy   9452974  0.059898         23
# 227       1            2         1   NVDA  buy   9452974  0.059898         23
# 228       1            3         1   NVDA  buy   9452974  0.059898         23
# ..      ...          ...       ...    ...  ...       ...       ...        ...
# 460       1          235         1   NVDA  buy       NaN       NaN        NaN
# 461       1          236         1   NVDA  buy       NaN       NaN        NaN
# 462       1          237         1   NVDA  buy       NaN       NaN        NaN
# 463       1          238         1   NVDA  buy       NaN       NaN        NaN
# 464       1          239         1   NVDA  buy       NaN       NaN        NaN
#
#     end_time time_horizon  arrival_price  order_vwap  shares_remaining  \
# 224      263          240     141.435059  141.427200         9452974.0
# 225      263          240     141.435059  141.568649         9339148.0
# 226      263          240     141.435059  141.451141         9213890.0
# 227      263          240     141.435059  141.330612         8971910.0
# 228      263          240     141.435059  141.248199         8835291.0
# ..       ...          ...            ...         ...               ...
# 460      NaN          240            NaN  141.886047               0.0
# 461      NaN          240            NaN  141.886047               0.0
# 462      NaN          240            NaN  141.886047               0.0
# 463      NaN          240            NaN  141.886047               0.0
# 464      NaN          240            NaN  141.886047               0.0
#
#      immediate_impact  accumulated_impact  last_fill_price  last_trade_size  \
# 224          0.000000            0.000000       141.427200              0.0
# 225          0.001000            0.001000       141.568649         113826.0
# 226          0.001049            0.001049       141.344360         125258.0
# 227          0.001458            0.001458       141.211533         241980.0
# 228          0.001096            0.001096       140.958038         136619.0
# ..                ...                 ...              ...              ...
# 460               NaN            0.000000       141.436752              0.0
# 461               NaN            0.000000       141.411224              0.0
# 462               NaN            0.000000       141.417480              0.0
# 463               NaN            0.000000       141.431244              0.0
# 464               NaN            0.000000       141.411301              0.0
#
#      vwap_price   mid_price  total_reward  current_volume  action_percentage  \
# 224  141.427200  141.435059  0.000000e+00        455305.0               0.00
# 225  141.427200  141.435059 -1.520609e+04        455305.0               0.25
# 226  141.196228  141.189941 -3.845414e+03        501033.0               0.25
# 227  141.005905  141.012512  5.024341e+04        967921.0               0.25
# 228  140.803757  140.797501  1.154134e+05        546477.0               0.25
# ..          ...         ...           ...             ...                ...
# 460  141.436752  141.461761 -7.244455e+08        220236.0                NaN
# 461  141.411224  141.415009 -7.287087e+08        200580.0                NaN
# 462  141.417480  141.434952 -7.329719e+08        170376.0                NaN
# 463  141.431244  141.437500 -7.372350e+08        137278.0                NaN
# 464  141.411301  141.412552 -7.414982e+08        137049.0                NaN
#
#              adv is_finished
# 224  157817872.0         NaN
# 225  157817872.0       False
# 226  157817872.0       False
# 227  157817872.0       False
# 228  157817872.0       False
# ..           ...         ...
# 460  157817872.0        True
# 461  157817872.0        True
# 462  157817872.0        True
# 463  157817872.0        True
# 464  157817872.0        True
#
# [241 rows x 24 columns]

# %% [markdown]
# **Evaluation**

# %%
render_plots.plot_orders(test_orders, num_orders=3)
# Out:
# Order 1 Info: {'order_idx': 0, 'ticker': 'NVDA', 'order_qty': 1302204, 'adv_pct': 0.008251310326159, 'start_time': 83, 'end_time': 306, 'time_horizon': 223, 'side': 'sell', 'arrival_price': 142.2449951171875, 'order_vwap': 142.24365234375, 'shares_remaining': 1302204, 'current_step': 0, 'immediate_impact': 0.0, 'accumulated_impact': 0.0, 'last_fill_price': 142.24365234375, 'last_trade_size': 0, 'vwap_price': 142.24365234375, 'mid_price': 142.2449951171875, 'total_reward': 0.0, 'current_volume': 346268.0, 'action_percentage': 0.0, 'adv': 157817872.0, 'episode': 0}
# Order 2 Info: {'order_idx': 1, 'ticker': 'NVDA', 'order_qty': 9452974, 'adv_pct': 0.05989799275994301, 'start_time': 23, 'end_time': 263, 'time_horizon': 240, 'side': 'buy', 'arrival_price': 141.43505859375, 'order_vwap': 141.4272003173828, 'shares_remaining': 9452974, 'current_step': 0, 'immediate_impact': 0.0, 'accumulated_impact': 0.0, 'last_fill_price': 141.4272003173828, 'last_trade_size': 0, 'vwap_price': 141.4272003173828, 'mid_price': 141.43505859375, 'total_reward': 0.0, 'current_volume': 455305.0, 'action_percentage': 0.0, 'adv': 157817872.0, 'episode': 1}
# Order 3 Info: {'order_idx': 2, 'ticker': 'AAPL', 'order_qty': 26203, 'adv_pct': 0.0005857248906977475, 'start_time': 350, 'end_time': 354, 'time_horizon': 4, 'side': 'buy', 'arrival_price': 200.55999755859375, 'order_vwap': 200.56375122070312, 'shares_remaining': 26203, 'current_step': 0, 'immediate_impact': 0.0, 'accumulated_impact': 0.0, 'last_fill_price': 200.56375122070312, 'last_trade_size': 0, 'vwap_price': 200.56375122070312, 'mid_price': 200.55999755859375, 'total_reward': 0.0, 'current_volume': 122023.0, 'action_percentage': 0.0, 'adv': 44735904.0, 'episode': 2}

# %% [markdown]
# ## References
#
# [1] Lehman, J. & Stanley, K. O. (2011). _Evolving a Diversity of Creatures through Novelty Search and Local Competition_. In Proceedings of the 13th Genetic and Evolutionary Computation Conference (GECCO) (pp. 211–218). ACM.
#
# [2] Pugh, J. K., Soros, L. B., & Stanley, K. O. (2016). _Quality Diversity: A New Frontier for Evolutionary Computation_. Frontiers in Robotics and AI, 3, 40.
#
# [3] Cully, A. & Demiris, Y. (2017). _Quality and Diversity Optimization: A Unifying Modular Framework_. arXiv:1708.09251.
#
# [4] Mouret, J.-B. & Clune, J. (2015). _Illuminating Search Spaces by Mapping Elites_. arXiv:1504.04909.
#
# [5] Cully, A., Clune, J., Tarapore, D., & Mouret, J.-B. (2015). _Robots That Can Adapt Like Animals_. Nature, 521(7553), 503–507.
#
# [6] Gaier, A., Asteroth, A., & Mouret, J.-B. (2017). _Data-Efficient Exploration, Optimization, and Modeling of Diverse Designs through Surrogate-Assisted Illumination_. arXiv:1702.03713.
#
# [7] Bouchaud, J.-P., Bonart, J., Donier, J., & Gould, M. (2018). _The Propagator Model_. In Trades, Quotes and Prices: Financial Markets Under the Microscope (pp. 252–253). Cambridge University Press.
#
# [8] Tóth, B., Lempérière, Y., Deremble, C., de Lataillade, J., Kockelkoren, J., & Bouchaud, J.-P. (2011). _Anomalous price impact and the critical nature of liquidity in financial markets_. Physical Review X, 1(2), 021006.

# %% [markdown]
# **Appendix**
#
#
# Final project To-Dos:
#
# * Train/Test split based on date ranges and new unseen symbols
# * Could we use unfilled quanity/EHV as a penalty to ensure it doesn't get too far behind so it can complete?
# * Find and break out days by different regimes, e.g. high volatility, low volatility, trending, mean reverting, shocks, stable markets, etc. add these to the gym
# * Add hypothetical slippage to the ultimate best price for the horizon to indicate opportunity cost
# * Consider more advanced propagator models such as the 6-event propagator model (ch. 14 of Trades, Quotes and Prices)
# * Utilize real order data for the impact model callibrations
# * Linear versus square root for 1 minute impact?
# * Make volume profiles to scale volume and remove auctions, remove special days
# * Add longer look-back on market data
# * TODO: fix the warnings in check env
# * TODO: fix warnings in geneerate orders
