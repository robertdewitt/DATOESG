# %% [markdown]
# #### **Machine Learning and Data Science Research Project - Research (Vectorized)**
#
# **Project:** Reinforcement Learning for Optimal Execution - GPU Accelerated Version
#
# **Author:** Robert de Witt (CID: 02541719)
#
# **Note:** This is a vectorized version optimized for GPU acceleration and faster training.

# %%
import time                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 
import pandas as pd
from notebook_logging_setup import quick_setup
from stable_baselines3 import PPO
from stable_baselines3.common.torch_layers import BaseFeaturesExtractor
from stable_baselines3.common.vec_env import VecNormalize
from tqdm import tqdm
import torch
import torch.nn as nn
import numpy as np
import random
import gc
import psutil
import tqdm

# my libraries
from mkt_data_mana import ManaMarketDataLoader as mmdl
import render_plots as rp
import model_parking as mp
from optimal_execution_env_vectorized import VectorizedMultiOrderExecutionEnv
from order_generator import OrderGenerator
from quote_and_trade_analytics import QuoteAndTradeAnalytics
import baseline_strategies as bs
import gpu_utils
from custom_tensorboard_callback import create_training_callbacks
from propagator_param_loader import PropagatorParamLoader
from cost_models import StandardExecutionCostModel
import ppo_optimizer as po


quick_setup(debug=False)
fixed_seed = 42
np.random.seed(fixed_seed)
random.seed(fixed_seed)  # Also seed the random module  

device = gpu_utils.get_torch_device()
gpu_utils.set_random_seed(fixed_seed)

print(f"Using device: {device}")
print(f"GPU Memory Available: {torch.cuda.get_device_properties(0).total_memory / 1024**3:.1f} GB" if device == 'cuda' else "")
print(f"MPS Available: {torch.backends.mps.is_available()}" if device == 'mps' else "")

# Vectorized environment configuration
max_trading_rate = 0.8
max_order_size_in_adv_pct = 0.1
num_vec_envs_gpu = 64 
num_vec_envs_cpu_train = 64
num_vec_envs_cpu_test = 512

print(f"Vectorized configuration:")
print(f"  - Num vectorized environments: GPU: {num_vec_envs_gpu} and CPU train: {num_vec_envs_cpu_train} and CPU test: {num_vec_envs_cpu_test}")
print(f"  - Device: {device}")
print(f"  - Max trading rate: {max_trading_rate}")
print(f"  - Max order size (ADV %): {max_order_size_in_adv_pct}")
# Out:
# 2025-08-28 20:28:52.629123: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-08-28 20:28:52.816559: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1756409332.909535  372273 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1756409332.930625  372273 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1756409333.094383  372273 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1756409333.094422  372273 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1756409333.094423  372273 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1756409333.094424  372273 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-08-28 20:28:53.116967: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Logging configured at INFO level
# 2025-08-28 20:28:57 - root - INFO - Using CUDA GPU: NVIDIA GeForce RTX 4090
# 2025-08-28 20:28:57 - root - INFO - CUDA Device Count: 1
# 2025-08-28 20:28:57 - root - INFO - Current CUDA Device: 0
# Using device: cuda
# GPU Memory Available: 24.0 GB
#
# Vectorized configuration:
#   - Num vectorized environments: GPU: 64 and CPU train: 64 and CPU test: 512
#   - Device: cuda
#   - Max trading rate: 0.8
#   - Max order size (ADV %): 0.1

# %%
# Stock selection - optimized for vectorized processing
tickers = None
#tickers = ['MSFT','GOOGL']

# Load market data with progress tracking
print("\nLoading market data...")
start_time = time.time()
md = mmdl(load_data=True)
load_time = time.time() - start_time
print(f"Data loaded in {load_time:.2f} seconds")

# Check available dates
print(f"Available dates: {md.start_date} to {md.end_date}")


all_stock_list = md.all_stock_list                                                      

if tickers is None:
    tickers = all_stock_list

# Check available symbols, wrap 15 symbols per row
print(f"Available symbols sample[0:15], total {len(all_stock_list)}:")
print(f"[(1:15)]{all_stock_list[0:15]},")

# get dataframe with market data
processing_time = time.time() - start_time
print(f"Data finished processing in {processing_time:.2f} seconds")
# Out:
# Loading market data...
# Data loaded in 16.13 seconds
# Available dates: 2022-01-03 to 2022-12-30
# Available symbols sample[0:15], total 402:
# [(1:15)]['A', 'AAL', 'AAP', 'AAPL', 'ABBV', 'ABT', 'ACGL', 'ACN', 'ADBE', 'ADI', 'ADM', 'ADP', 'ADSK', 'AEE', 'AEP'],
# Data finished processing in 34.82 seconds

# %%
# Create train/test split using date filtering with larger batches for vectorized processing
start_time = time.time()

train_stock_df_list = md.to_pandas_dict_fast(start_pct=0.0, end_pct=0.7)
test_stock_df_list = md.to_pandas_dict_fast(start_pct=0.71, end_pct=1.0)
print(f"to_pandas_dict time: {time.time() - start_time:0.2f} seconds")
print(f"train_stock_df_list: {train_stock_df_list.keys()}")
# print head of train_stock_df_list in a nicer format, show all columns in one line
print(f"train_stock_df_list: {train_stock_df_list[tickers[0]].head(2).to_string(index=False)}")
print(f"train_stock_df_list: {train_stock_df_list[tickers[1]].head(2).to_string(index=False)}")
print(f"train_stock_df_list time: {time.time() - start_time:0.2f} seconds")
# Out:
# 2025-08-28 20:29:58 - mkt_data_mana - INFO - start_date: 2022-01-03, end_date: 2022-09-13, num_dates: 165
# 2025-08-28 20:29:58 - mkt_data_mana - INFO - Loaded data for 393 symbols: ['A', 'AAL', 'AAP', 'AAPL', 'ABBV', 'ABT', 'ACN', 'ADBE', 'ADI', 'ADM']...
# 2025-08-28 20:30:16 - mkt_data_mana - INFO - start_date: 2022-09-16, end_date: 2022-12-30, num_dates: 71
# 2025-08-28 20:30:16 - mkt_data_mana - INFO - Loaded data for 394 symbols: ['A', 'AAL', 'AAP', 'AAPL', 'ABBV', 'ABT', 'ACGL', 'ACN', 'ADBE', 'ADI']...
# to_pandas_dict time: 45.36 seconds
# train_stock_df_list: dict_keys(['A', 'AAL', 'AAP', 'AAPL', 'ABBV', 'ABT', 'ACN', 'ADBE', 'ADI', 'ADM', 'ADP', 'ADSK', 'AEE', 'AEP', 'AES', 'AFL', 'AJG', 'AKAM', 'ALB', 'ALGN', 'ALK', 'AMAT', 'AMCR', 'AMD', 'AME', 'AMGN', 'AMP', 'AMT', 'AMZN', 'ANET', 'ANSS', 'AON', 'AOS', 'APA', 'APD', 'APH', 'ARE', 'ATO', 'ATVI', 'AVB', 'AVGO', 'AWK', 'AXP', 'BA', 'BALL', 'BAX', 'BBWI', 'BBY', 'BDX', 'BEN', 'BIIB', 'BK', 'BKNG', 'BKR', 'BLK', 'BMY', 'BRO', 'BWA', 'BXP', 'CAG', 'CAH', 'CARR', 'CAT', 'CB', 'CBRE', 'CCI', 'CCL', 'CDAY', 'CDNS', 'CDW', 'CE', 'CEG', 'CERN', 'CF', 'CHD', 'CHRW', 'CHTR', 'CI', 'CINF', 'CL', 'CLX', 'CMA', 'CMCSA', 'CME', 'CMI', 'CNC', 'CNP', 'COP', 'COST', 'CPB', 'CPRT', 'CPT', 'CRM', 'CSCO', 'CSX', 'CTLT', 'CTRA', 'CTSH', 'CTVA', 'CVS', 'CVX', 'CZR', 'D', 'DAL', 'DD', 'DE', 'DFS', 'DG', 'DGX', 'DHI', 'DIS', 'DISCK', 'DISH', 'DLTR', 'DOV', 'DOW', 'DRE', 'DRI', 'DTE', 'DVN', 'DXC', 'DXCM', 'EA', 'EBAY', 'ECL', 'ED', 'EIX', 'EL', 'EMN', 'EMR', 'ENPH', 'EOG', 'EPAM', 'EQR', 'ES', 'ETN', 'ETR', 'ETSY', 'EVRG', 'EW', 'EXC', 'EXPD', 'EXPE', 'FANG', 'FAST', 'FCX', 'FDX', 'FE', 'FIS', 'FITB', 'FMC', 'FOX', 'FOXA', 'FTNT', 'FTV', 'GD', 'GE', 'GILD', 'GIS', 'GLW', 'GM', 'GNRC', 'GOOG', 'GOOGL', 'GPC', 'GPN', 'GPS', 'GRMN', 'HAL', 'HAS', 'HBAN', 'HCA', 'HD', 'HES', 'HLT', 'HOLX', 'HON', 'HPE', 'HPQ', 'HRL', 'HSIC', 'HST', 'HSY', 'HUM', 'IBM', 'ICE', 'IFF', 'ILMN', 'INCY', 'INFO', 'INTC', 'INTU', 'IP', 'IPG', 'IQV', 'IR', 'IRM', 'ISRG', 'ITW', 'IVZ', 'JCI', 'JNJ', 'JNPR', 'K', 'KDP', 'KEYS', 'KHC', 'KLAC', 'KMB', 'KMI', 'KMX', 'KO', 'KR', 'L', 'LEN', 'LH', 'LHX', 'LIN', 'LKQ', 'LLY', 'LMT', 'LNC', 'LNT', 'LOW', 'LRCX', 'LUMN', 'LUV', 'LVS', 'LW', 'LYB', 'LYV', 'MA', 'MAR', 'MAS', 'MCD', 'MCHP', 'MCK', 'MCO', 'MDLZ', 'MDT', 'META', 'MGM', 'MMC', 'MMM', 'MNST', 'MO', 'MOS', 'MPC', 'MRK', 'MRNA', 'MRO', 'MSFT', 'MTCH', 'MU', 'NCLH', 'NDAQ', 'NEM', 'NFLX', 'NKE', 'NLSN', 'NOC', 'NOW', 'NRG', 'NSC', 'NTAP', 'NTRS', 'NUE', 'NVDA', 'NWL', 'NWSA', 'NXPI', 'O', 'ODFL', 'OGN', 'OKE', 'OMC', 'ON', 'ORCL', 'ORLY', 'OTIS', 'OXY', 'PARA', 'PAYX', 'PBCT', 'PCAR', 'PEAK', 'PEG', 'PENN', 'PEP', 'PFE', 'PFG', 'PG', 'PGR', 'PHM', 'PLD', 'PM', 'PNR', 'PNW', 'PPG', 'PPL', 'PRU', 'PSX', 'PVH', 'PWR', 'PXD', 'PYPL', 'QCOM', 'QRVO', 'RCL', 'REG', 'REGN', 'RHI', 'RL', 'ROK', 'ROL', 'ROST', 'RSG', 'RTX', 'SBUX', 'SEDG', 'SEE', 'SHW', 'SJM', 'SLB', 'SNPS', 'SO', 'SPGI', 'SRE', 'STX', 'STZ', 'SWK', 'SWKS', 'SYK', 'SYY', 'TAP', 'TEL', 'TER', 'TGT', 'TJX', 'TMO', 'TMUS', 'TPR', 'TRMB', 'TROW', 'TRV', 'TSCO', 'TSLA', 'TSN', 'TT', 'TTWO', 'TWTR', 'TXN', 'TXT', 'UA', 'UAA', 'UAL', 'UDR', 'ULTA', 'UNH', 'UNP', 'UPS', 'URI', 'V', 'VFC', 'VICI', 'VLO', 'VRSK', 'VRSN', 'VRTX', 'VTR', 'VTRS', 'VZ', 'WBA', 'WBD', 'WDC', 'WEC', 'WELL', 'WHR', 'WM', 'WMB', 'WMT', 'WRK', 'WY', 'WYNN', 'XEL', 'XLNX', 'XOM', 'XRAY', 'XYL', 'YUM', 'ZBH', 'ZION', 'ZTS'])
# train_stock_df_list:     time  trade_count  trade_volume  trade_last  trade_high  trade_low  bid_price  bid_size  ask_price  ask_size  hid_vol  buy_vol  sell_vol  unsided_vol       vwap
# 09:30:00          2.0           8.0  159.149994  159.440002 159.149994 159.039993       1.0 160.139999     202.0      8.0      0.0       8.0          0.0 159.440002
# 09:31:00         63.0         996.0  158.669998  159.389999 158.580002 158.589996     415.0 159.100006     202.0    996.0      0.0     996.0          0.0 158.825302
# train_stock_df_list:     time  trade_count  trade_volume  trade_last  trade_high  trade_low  bid_price  bid_size  ask_price  ask_size  hid_vol  buy_vol  sell_vol  unsided_vol      vwap
# 09:30:00         15.0        4899.0       18.23       18.23  18.190001  18.219999   36022.0      18.23   14475.0   4899.0   4899.0       0.0          0.0 18.229601
# 09:31:00       1092.0      235322.0       18.23       18.33  18.219999  18.230000     500.0      18.24    9870.0 235322.0 159289.0   76033.0          0.0 18.280800
# train_stock_df_list time: 45.37 seconds

# %% [markdown]
# **Order Generation**
#
# The order generation process creates a set of trading orders with the following characteristics:
# 1.  For each order, a random stock is selected from the available universe, and its Average Daily Volume (ADV) is calculated as the mean of daily trading volumes.
# 2. The order size is determined by sampling a random percentage of ADV between min_adv_pct and max_adv_pct, scaled by the time horizon (as a fraction of the trading day). This ensures that larger orders are spread over longer time periods and that the orders can complete within the time horizon given
# 3. The execution window is defined by randomly selecting a start time and a time horizon (in minutes) between min_time_horizon and max_time_horizon, with the end time being start_time + time_horizon.
# 4. Each order is assigned a random side (buy/sell) and its quantity is rounded to the nearest integer, with safeguards to prevent zero-sized orders. The resulting orders are then used to train or evaluate the execution strategy in the reinforcement learning environment.
# 5. For simplicity's sake, we will not apply order constraints such as limit prices or volume limits, we will assume lit market trading only and we will not worry about auctions.

# %%
print("Generating training orders...")
import importlib
import order_generator 
import propagator_param_loader

importlib.reload(order_generator)
importlib.reload(propagator_param_loader)

from order_generator import OrderGenerator
from propagator_param_loader import PropagatorParamLoader

loader = PropagatorParamLoader("mana_data/propagator_model_data_cross_validation")

# TODO: make more robust to use max days symbol not just the random symbol in [0]
train_date_range = OrderGenerator.get_dates_from_dataframe(train_stock_df_list[tickers[0]])
test_date_range = OrderGenerator.get_dates_from_dataframe(test_stock_df_list[tickers[0]])

print(f"Train date range: {train_date_range[0]} to {train_date_range[-1]}")
print(f"Test date range: {test_date_range[0]} to {test_date_range[-1]}")

# load daily mana analytics
daily_analytics = QuoteAndTradeAnalytics(symbols=tickers)

train_orders_df = OrderGenerator(
    stock_df_list=train_stock_df_list,
    md_source='mana',
    market_data=md, 
    debug=False,
    dates=train_date_range,
    analytics=daily_analytics,
    max_adv_pct=max_order_size_in_adv_pct, 
    propagator_loader=loader,
    num_orders=25000,
    y_column='Y_best',
    tau_column='tau_best',
    seed=fixed_seed
).get_orders()

train_time = time.time() - start_time
print(f"Training orders generated in {train_time:.2f} seconds")

print("Generating test orders...")
start_time = time.time()

# Test set: last 2 days (exclude first 5 days) - larger batch for vectorized processing
test_orders_df = OrderGenerator(
    stock_df_list=test_stock_df_list,
    md_source='mana',
    market_data=md, 
    debug=False,
    dates=test_date_range,
    analytics=daily_analytics,
    max_adv_pct=max_order_size_in_adv_pct, 
    propagator_loader=loader,
    num_orders=7500,
    y_column='Y_best',
    tau_column='tau_best',
    seed=fixed_seed
).get_orders()

test_time = time.time() - start_time
print(f"Test orders generated in {test_time:.2f} seconds")

# Verify the date split
print(f"\nTrain set: {len(train_orders_df)} orders")
print(f"Train dates: {train_orders_df['date'].min()} to {train_orders_df['date'].max()}")
#print(f"Orders per day (train):\n{train_orders_df['date'].value_counts().sort_index()}")

print(f"\nTest set: {len(test_orders_df)} orders")
print(f"Test dates: {test_orders_df['date'].min()} to {test_orders_df['date'].max()}")
#print(f"Orders per day (test):\n{test_orders_df['date'].value_counts().sort_index()}")

train_idx = pd.DatetimeIndex(train_date_range)
test_idx  = pd.DatetimeIndex(test_date_range)

# Verify no overlap
print(f"No overlap verified: {len(train_idx.intersection(test_idx)) == 0}")
# Out:
# Generating training orders...
# 2025-08-28 20:30:18 - propagator_param_loader - INFO - PropagatorParamLoader initialized with 388 symbols
# Train date range: 2022-01-03 to 2022-09-13
# Test date range: 2022-09-16 to 2022-12-30
# 2025-08-28 20:30:18 - quote_and_trade_analytics - INFO - Loading analytics from: mana_data/daily_analytics_parquet
# 2025-08-28 20:30:18 - quote_and_trade_analytics - INFO - Found 402 symbol directories
# 2025-08-28 20:33:18 - quote_and_trade_analytics - INFO - Successfully loaded analytics for 402 symbols
# 2025-08-28 20:33:18 - quote_and_trade_analytics - INFO - Available analytics columns: ['symbol', 'adv_21_days', 'avg_trade_count_21_days', 'avg_spread_21_days', 'avg_depth_21_days', 'vwap', 'daily_volatility', 'daily_volatility_lag1', 'daily_volatility_5d']
# 2025-08-28 20:33:18 - order_generator - INFO - Generating 25000 orders for 393 stocks across 165 dates
# 2025-08-28 20:33:18 - order_generator - INFO - Date range: 2022-01-03 to 2022-09-13
# 2025-08-28 20:33:18 - order_generator - INFO - Building availability matrix and computing ADV...
# Availability Matrix Stocks: A to ZTS
# Availability Matrix Dates: 2022-01-03 to 2022-09-13
# 2025-08-28 20:35:28 - order_generator - INFO - Matrix built in 130.06s
# 2025-08-28 20:35:28 - order_generator - INFO - Generating valid orders...
# 2025-08-28 20:35:28 - order_generator - INFO - Orders sampled in 0.01s
# 2025-08-28 20:35:28 - order_generator - INFO - Generating order parameters...
# 2025-08-28 20:35:28 - order_generator - INFO - Parameters generated in 0.00s
# 2025-08-28 20:35:28 - order_generator - INFO - Loading analytics...
# 2025-08-28 20:35:34 - order_generator - INFO - Analytics loaded in 5.90s
# 2025-08-28 20:35:34 - order_generator - INFO - Loading propagator parameters...
# 2025-08-28 20:35:34 - order_generator - INFO - Loading propagator parameters (Y and tau)...
# 2025-08-28 20:35:35 - propagator_param_loader - INFO -   Sample path would be: mana_data/propagator_model_data_cross_validation/sym=TT/date=20220328/daily_params.parquet
# 2025-08-28 20:35:35 - propagator_param_loader - INFO -   Sample path exists: True
# 2025-08-28 20:35:35 - propagator_param_loader - INFO -   Symbol_date_pairs: ('TT', datetime.date(2022, 3, 28)) to ('NVDA', datetime.date(2022, 8, 23))
# 2025-08-28 20:35:58 - propagator_param_loader - INFO - PropagatorParamLoader: Loaded 20609/20683 parameter sets (74 missing)
# 2025-08-28 20:35:58 - order_generator - INFO - Loaded Y parameters for 24918/25000 orders (99.7%)
# 2025-08-28 20:35:58 - order_generator - INFO - Loaded tau parameters for 24918/25000 orders (99.7%)
# 2025-08-28 20:35:58 - order_generator - INFO - Y statistics: mean=0.000077, std=0.000099, range=[0.000005, 0.000703]
# 2025-08-28 20:35:58 - order_generator - INFO - tau statistics: mean=66.34, std=57.32, range=[0.77, 180.00]
# 2025-08-28 20:35:58 - order_generator - INFO - Propagator parameters loaded in 23.20s
# 2025-08-28 20:35:58 - order_generator - INFO - Calculating intra-order returns...
# 2025-08-28 20:36:45 - order_generator - INFO - Returns calculated in 47.25s
# 2025-08-28 20:36:45 - order_generator - INFO - Generated 25000 orders in 206.45s total
# Training orders generated in 432.49 seconds
# Generating test orders...
# 2025-08-28 20:36:45 - order_generator - INFO - Generating 7500 orders for 394 stocks across 71 dates
# 2025-08-28 20:36:45 - order_generator - INFO - Date range: 2022-09-16 to 2022-12-30
# 2025-08-28 20:36:45 - order_generator - INFO - Building availability matrix and computing ADV...
# Availability Matrix Stocks: A to ZTS
# Availability Matrix Dates: 2022-09-16 to 2022-12-30
# 2025-08-28 20:37:13 - order_generator - INFO - Matrix built in 28.55s
# 2025-08-28 20:37:13 - order_generator - INFO - Generating valid orders...
# 2025-08-28 20:37:13 - order_generator - INFO - Orders sampled in 0.00s
# 2025-08-28 20:37:13 - order_generator - INFO - Generating order parameters...
# 2025-08-28 20:37:13 - order_generator - INFO - Parameters generated in 0.00s
# 2025-08-28 20:37:13 - order_generator - INFO - Loading analytics...
# 2025-08-28 20:37:15 - order_generator - INFO - Analytics loaded in 1.73s
# 2025-08-28 20:37:15 - order_generator - INFO - Loading propagator parameters...
# 2025-08-28 20:37:15 - order_generator - INFO - Loading propagator parameters (Y and tau)...
# 2025-08-28 20:37:15 - propagator_param_loader - INFO -   Sample path would be: mana_data/propagator_model_data_cross_validation/sym=TGT/date=20221205/daily_params.parquet
# 2025-08-28 20:37:15 - propagator_param_loader - INFO -   Sample path exists: True
# 2025-08-28 20:37:15 - propagator_param_loader - INFO -   Symbol_date_pairs: ('TGT', datetime.date(2022, 12, 5)) to ('CZR', datetime.date(2022, 12, 7))
# 2025-08-28 20:37:21 - propagator_param_loader - INFO - PropagatorParamLoader: Loaded 6445/6512 parameter sets (67 missing)
# 2025-08-28 20:37:21 - order_generator - INFO - Loaded Y parameters for 7420/7500 orders (98.9%)
# 2025-08-28 20:37:21 - order_generator - INFO - Loaded tau parameters for 7420/7500 orders (98.9%)
# 2025-08-28 20:37:21 - order_generator - INFO - Y statistics: mean=0.000072, std=0.000093, range=[0.000004, 0.000614]
# 2025-08-28 20:37:21 - order_generator - INFO - tau statistics: mean=67.52, std=58.13, range=[0.17, 180.00]
# 2025-08-28 20:37:21 - order_generator - INFO - Propagator parameters loaded in 6.40s
# 2025-08-28 20:37:21 - order_generator - INFO - Calculating intra-order returns...
# 2025-08-28 20:37:29 - order_generator - INFO - Returns calculated in 7.04s
# 2025-08-28 20:37:29 - order_generator - INFO - Generated 7500 orders in 43.73s total
# Test orders generated in 43.73 seconds
#
# Train set: 25000 orders
# Train dates: 2022-01-03 to 2022-09-13
#
# Test set: 7500 orders
# Test dates: 2022-09-16 to 2022-12-30
# No overlap verified: True

# %%
import importlib
import render_plots as rp

importlib.reload(rp)

# print orders dataframe in single line per order
rp.display_order_info(train_orders_df, name='Sample Train', num_orders=3)
rp.display_order_info(test_orders_df, name='Sample Test', num_orders=3)
rp.plot_order_histograms(train_orders_df, test_orders_df)

# Show sample orders with dates
print("\nSample train orders with dates:")
print(train_orders_df[['ticker', 'date', 'start_time', 'end_time', 'order_qty', 'side']].head(5))
print("\nSample test orders with dates:")
print(test_orders_df[['ticker', 'date', 'start_time', 'end_time', 'order_qty', 'side']].head(5))
# Out:
# 3 Sample Train Orders:
# ========================================
# Sample Train (1): ticker: TT order_qty: 235 adv_pct: 0.05% ehv_pct: 0.44% adv: 462,702 date: 2022-03-28 start_time: 61 end_time: 106 time_horizon: 45 side: sell avg_spread_21_days: 0.0006239091293154752 avg_depth_21_days: 124.59109860374814 daily_volatility: 0.010320264233670523 daily_volatility_lag1: 0.01072888123505362 daily_volatility_5d: 0.010521842845469224 daily_vwap: 156.28431701660156 intra_order_return: 0.0026203340385109186 adv_21_days: 462702.14285714284 avg_trade_count_21_days: 16938.52380952381 Y: 2.6505124450365613e-05 tau: 67.88558239023628
# Sample Train (2): ticker: CTSH order_qty: 83458 adv_pct: 6.86% ehv_pct: 7.62% adv: 1,215,905 date: 2022-02-07 start_time: 18 end_time: 370 time_horizon: 352 side: buy avg_spread_21_days: 0.00039664058149581566 avg_depth_21_days: 364.0829351515997 daily_volatility: 0.015808740704434863 daily_volatility_lag1: 0.015967082111434175 daily_volatility_5d: 0.017525966506237476 daily_vwap: 87.58821105957031 intra_order_return: 0.014099170453846455 adv_21_days: 1215904.6666666667 avg_trade_count_21_days: 24359.47619047619 Y: 0.0001670389033513995 tau: 11.169047501182417
# Sample Train (3): ticker: ABT order_qty: 12422 adv_pct: 0.54% ehv_pct: 2.82% adv: 2,293,783 date: 2022-02-23 start_time: 140 end_time: 215 time_horizon: 75 side: sell avg_spread_21_days: 0.00022137408670442048 avg_depth_21_days: 397.1729409354074 daily_volatility: 0.009372041606791798 daily_volatility_lag1: 0.012433916134620235 daily_volatility_5d: 0.017423037550089254 daily_vwap: 118.01871490478516 intra_order_return: -0.007422379218041897 adv_21_days: 2293783.095238095 avg_trade_count_21_days: 44933.57142857143 Y: 9.051668984115638e-05 tau: 8.14893007374098
# ========================================
# 3 Sample Test Orders:
# ========================================
# Sample Test (1): ticker: TGT order_qty: 34100 adv_pct: 1.93% ehv_pct: 3.50% adv: 1,771,194 date: 2022-12-05 start_time: 118 end_time: 333 time_horizon: 215 side: buy avg_spread_21_days: 0.0004620151872934124 avg_depth_21_days: 211.7696998232887 daily_volatility: 0.031037534296488953 daily_volatility_lag1: 0.02282752629352428 daily_volatility_5d: 0.019915255764325592 daily_vwap: 157.26687622070312 intra_order_return: -0.014206361025571823 adv_21_days: 1771194.4285714286 avg_trade_count_21_days: 55901.57142857143 Y: 2.575384799095692e-05 tau: 179.9307423027749
# Sample Test (2): ticker: LOW order_qty: 47012 adv_pct: 4.33% ehv_pct: 5.96% adv: 1,086,486 date: 2022-11-02 start_time: 101 end_time: 385 time_horizon: 284 side: buy avg_spread_21_days: 0.0004702388201936909 avg_depth_21_days: 195.47393835158576 daily_volatility: 0.028787966121269742 daily_volatility_lag1: 0.025951720285801675 daily_volatility_5d: 0.020223616315059697 daily_vwap: 191.1790771484375 intra_order_return: -0.03568272665143013 adv_21_days: 1086486.2857142857 avg_trade_count_21_days: 38951.90476190476 Y: 3.263348119571419e-05 tau: 44.83651234614926
# Sample Test (3): ticker: ADSK order_qty: 3628 adv_pct: 0.93% ehv_pct: 1.71% adv: 390,243 date: 2022-11-18 start_time: 148 end_time: 360 time_horizon: 212 side: sell avg_spread_21_days: 0.0009384336145305557 avg_depth_21_days: 115.67379034133185 daily_volatility: 0.027388249408881165 daily_volatility_lag1: 0.02209927890113339 daily_volatility_5d: 0.021161630823134672 daily_vwap: 211.340087890625 intra_order_return: 0.0038464164827018976 adv_21_days: 390243.38095238095 avg_trade_count_21_days: 23336.619047619046 Y: 3.807948214080645e-05 tau: 73.06299804935229
# ========================================
# Sample train orders with dates:
#   ticker        date  start_time  end_time  order_qty  side
# 0     TT  2022-03-28          61       106        235  sell
# 1   CTSH  2022-02-07          18       370      83458   buy
# 2    ABT  2022-02-23         140       215      12422  sell
# 3   MCHP  2022-05-26          19       389     117870  sell
# 4    XYL  2022-01-25         159       386      23596  sell
#
# Sample test orders with dates:
#   ticker        date  start_time  end_time  order_qty  side
# 0    TGT  2022-12-05         118       333      34100   buy
# 1    LOW  2022-11-02         101       385      47012   buy
# 2   ADSK  2022-11-18         148       360       3628  sell
# 3   CHTR  2022-10-27           1       367      12957  sell
# 4    RCL  2022-11-09         148       225       1079  sell

# %% [markdown]
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         **RL Environment**
#
# In the current setup the agent’s **state** at each step is a 14-dimensional real vector
# $$
# s_t = \bigl[p_t^{\rm mid},\,V_t,\,T - t,\,q_t,\,\alpha,\,x,\,f,\,m,\,\delta,\,A,\,p_0,\,r,\,v^{(1)},\,v^{(5)}\bigr],
# $$
# where it sees the current mid-price, market volume, time and shares remaining, target participation rate, trading signals, last fill and trade stats, arrival price, regime and short/long‐term volatilities.  Its **action**
# $$
# a_t \in \{-1.0,\,-0.75,\, -0.5,\,-0.25,\,-0.1,\,0,\,0.10,\,0.15,\,0.25,\,0.50,\,0.75,\ 1.0\}
# $$
# is “accelerate or decelerate versus the constant rate to trade this fraction of today’s volume,” so the env executes
# $$
# \Delta q_t = \min(\rho_i(1 + a_t)\,V_t,\;q_t)
# $$
# shares (and updates
# $$
# q_{t+1} = q_t - \Delta q_t
# $$
#
# $$\rho_i = \frac{Q_i}{V[t_{start}, t_{end}]}$$
# and the running VWAP).  Episodes end when either all shares are filled or the time horizon is hit, a large penalty is applied if the order does not complete.
#
#
# **Trading Simulation**
#
# In order to realistically simulate market behaviour, each trade needs to create an impact on price, and successive trades must propagate impact to the next order and so on. Rather than consider the nuance of trade by trade, limit and market orders and order books which require many assumptions and complex limit order book simulators, we focus on minutely percentage of volume trading. This allows to focus on building an optimal scheduling algorithm and removes the granular complexities of limit order books, order types and venue types.
#
# For minutely impact level impact estimations have utilized the transient impact model 2 from Bouchaud's book Trades, Quotes and Prices [7] which is parameterized with intuitive default values for this update and assumes the 1 minute trade impact follows square root.  We account for gaps between 1 minute trade intervals allowing for more accurate decay. In the final report, we will include a calibrated version of this model based on the trades observed via Bank of America's trade data.
#
#
# **Linear Transient‐Impact (Propagator) Model [7]**
# $$
# r_t \;=\;\sum_{t'<t} G(t - t')\,\epsilon_{t'} \;+\;\eta_t,
# $$
# where $r_t = P_t - P_{t-1}$ is the mid-price return, $\epsilon_{t'}\!=\pm1$ the sign of the trade at time $t'$, $G(\tau)$ the propagator kernel, and $\eta_t$ an uncorrelated noise term.
#
# In our case we do allow for non-uniformity of time steps between trades so we modify to consider the $t_{\Delta}$:
#
# $$
# \lambda(\Delta t)
# \;=\;
# \exp\!\Bigl(-\frac{\Delta t}{\tau}\Bigr),
# \quad
# \Delta I_t
# \;=\;
# Y\,\sigma\,\sqrt{\frac{q_t}{V}},
# $$
#
# $$
# I_t
# \;=\;
# \lambda(\Delta t)\,I_{t-1}
# \;+\;
# \Delta I_t,
# $$
#
# $$
# p_t^{\mathrm{fill}}
# \;=\;
# p_t^{\mathrm{vwap}}
# \bigl(1 \;+\; s\,I_t\bigr).
# $$

# %%
# Create vectorized execution environments for training
print("Creating vectorized training environment...")
import importlib
import optimal_execution_env_vectorized as oeev
import cost_models
importlib.reload(oeev)
importlib.reload(cost_models)
from cost_models import StandardExecutionCostModel

rl_cost_model = StandardExecutionCostModel()
PPO_GAMMA = 0.999  

print("Creating CPU training environment...")

# Use the new vectorized environment with wrapper for training
train_execution_cpu_env = oeev.VectorizedMultiOrderExecutionEnv(
    stock_df_list=train_stock_df_list,
    orders_df=train_orders_df,
    impact_coef=1,
    decay_rate=5,
    num_envs=num_vec_envs_cpu_train,  
    min_rate=0,
    max_rate=max_trading_rate,
    device='cpu',
    seed=fixed_seed,
    cost_model=rl_cost_model
)

train_execution_cpu_env = VecNormalize(
    train_execution_cpu_env,
    norm_obs=True, norm_reward=True,
    clip_obs=10., clip_reward=10.,
    gamma=PPO_GAMMA,   
)

# Check environment
print("OK: Vectorized cpu train environment loaded!")

# Create vectorized execution environments for testing (direct access for execution)
print("\nCreating vectorized cpu test environment...")


# for compatibility with training environment, create a GPU (if available) and CPU environment
if device in ["cuda", "mps"]:

    print("Initializing VectorizedMultiOrderExecutionEnv with training wrapper for GPU for training")

    train_execution_gpu_env = oeev.VectorizedMultiOrderExecutionEnv(
        stock_df_list=train_stock_df_list,
        orders_df=train_orders_df,
        impact_coef=1,
        decay_rate=5,
        num_envs=num_vec_envs_gpu,  
        min_rate=0,
        max_rate=max_trading_rate,
        device=device,
        seed=fixed_seed
    )

    train_execution_gpu_env = VecNormalize(
        train_execution_gpu_env,
        norm_obs=True, norm_reward=True,
        clip_obs=10., clip_reward=10.,
        gamma=PPO_GAMMA,   
    )   

    print("OK: VectorizedMultiOrderExecutionEnv with training wrapper for GPU for training loaded!")

    # Create vectorized execution environments for testing (direct access for execution)
    print("\nCreating vectorized gpu test environment...")
 
    test_execution_gpu_env = oeev.VectorizedMultiOrderExecutionEnv(
        stock_df_list=test_stock_df_list,
        orders_df=test_orders_df,
        impact_coef=1,
        decay_rate=5,
        num_envs=num_vec_envs_gpu,  
        min_rate=0,
        max_rate=max_trading_rate,
        device=device,
        seed=fixed_seed
    )
    
    print("OK: Vectorized gpu test environment check loaded!")

else:
    print("No GPU available, using CPU for training and testing")
    train_execution_gpu_env = train_execution_cpu_env
    test_execution_gpu_env = test_execution_cpu_env


print(f"\nVectorized Environment Summary:")
print(f"  - Training orders: {len(train_orders_df)}")
print(f"  - Test orders: {len(test_orders_df)}")
print(f"  - Vectorized environments: GPU: {num_vec_envs_gpu} and CPU train: {num_vec_envs_cpu_train} and CPU test: {num_vec_envs_cpu_test}")
if device in ["cuda", "mps"]:
    print(f"  - Device: {device} + CPU")
else:
    print(f"  - Device: cpu")
# Out:
# Creating vectorized training environment...
# Creating CPU training environment...
# 2025-08-28 20:37:30 - optimal_execution_env_vectorized - INFO - Using device: cpu (explicitly set)
# OK: Vectorized cpu train environment loaded!
#
# Creating vectorized cpu test environment...
# 2025-08-28 20:37:33 - optimal_execution_env_vectorized - INFO - Using device: cpu (explicitly set)
# OK: Vectorized cpu test environment loaded!
# Initializing VectorizedMultiOrderExecutionEnv with training wrapper for GPU for training
# 2025-08-28 20:37:34 - optimal_execution_env_vectorized - INFO - Using device: cuda (explicitly set)
# OK: VectorizedMultiOrderExecutionEnv with training wrapper for GPU for training loaded!
#
# Creating vectorized gpu test environment...
# 2025-08-28 20:37:37 - optimal_execution_env_vectorized - INFO - Using device: cuda (explicitly set)
# OK: Vectorized gpu test environment check loaded!
#
# Vectorized Environment Summary:
#   - Training orders: 25000
#   - Test orders: 7500
#   - Vectorized environments: GPU: 64 and CPU train: 64 and CPU test: 512
#   - Device: cuda + CPU

# %%
# Set up environment for RL training 

importlib.reload(mp)
import ppo_optimizer as po
importlib.reload(po)


# Set up vectorized model parking and train a simple model
mp_vec = mp.ModelParking()

callbacks = create_training_callbacks(
    enable_custom=True,      # Enable custom TensorBoard logging
    enable_env_stats=True,   # Enable environment-specific stats
    enable_debug=False,      # Disable debug logging (can be verbose)
    verbose=0
)

num_orders_per_episode = 24000
num_train_steps = 390/2 * num_orders_per_episode

# Memory cleanup before training
if device != 'cpu':
    torch.cuda.empty_cache() if device == 'cuda' else None
    gc.collect()
    print("GPU memory cleaned")
# Out:
# 2025-08-28 20:37:38 - root - INFO - ModelParking initialized without cached models.
# GPU memory cleaned

# %%
# Train a simple vectorized PPO model
model_name = "ppo_multiorder_exec_vec"
print(f"\nTraining model: {model_name}")
start_time = time.time()

policy_kwargs = dict(
    features_extractor_kwargs=dict(features_dim=256),
    net_arch=dict(pi=[256, 256], vf=[256, 256]), 
    activation_fn=torch.nn.ReLU
    )

po.train_ppo_fast(train_execution_cpu_env, model_name, num_train_steps, callbacks=callbacks, 
               mp_vec=mp_vec, ppo_kwargs=policy_kwargs, device="cpu", ppo_gamma=PPO_GAMMA)
# Out:
# Training model: ppo_multiorder_exec_vec
#
# ============================================================
# OPTIMIZED PPO TRAINING: ppo_multiorder_exec_vec
# ============================================================
# Using cpu device
# 2025-08-28 20:37:39 - root - INFO -
# Optimized Training Configuration for ppo_multiorder_exec_vec_nsteps_2048_batchsize_8192_epochs_3:
# 2025-08-28 20:37:39 - root - INFO -   - Parallel environments: 64
# 2025-08-28 20:37:39 - root - INFO -   - Steps per rollout: 2048
# 2025-08-28 20:37:39 - root - INFO -   - Total samples per rollout: 131,072
# 2025-08-28 20:37:39 - root - INFO -   - Batch size: 8,192
# 2025-08-28 20:37:39 - root - INFO -   - Mini-batches per epoch: 16
# 2025-08-28 20:37:39 - root - INFO -   - Epochs per update: 3
# 2025-08-28 20:37:39 - root - INFO -   - Approximate updates per second: 20.8
# optimizer lr at init: 0.0003
#
# Training ppo_multiorder_exec_vec_nsteps_2048_batchsize_8192_epochs_3 for 4,680,000.0 timesteps...
# Using 16 CPU threads for training
# 2025-08-28 20:37:39 - optimal_execution_env_vectorized - WARNING - Found 1 NaN or non-positive Y values, replacing with median 3.425368892382277e-05
# 2025-08-28 20:37:39 - optimal_execution_env_vectorized - WARNING - Found 1 NaN or non-positive tau values, replacing with median 43.281536986057944
# Logging to ./tensorboard_logs/ppo_multiorder_exec_vec_nsteps_2048_batchsize_8192_epochs_3/PPO_5
# ---------------------------------------------------------------------
# | custom/                    |                                      |
# |    action_0_prob           | 0.109                                |
# |    action_10_prob          | 0.0781                               |
# |    action_1_prob           | 0.141                                |
# |    action_2_prob           | 0.0625                               |
# |    action_3_prob           | 0.0781                               |
# |    action_4_prob           | 0.0781                               |
# |    action_5_prob           | 0.109                                |
# |    action_6_prob           | 0.109                                |
# |    action_7_prob           | 0.0625                               |
# |    action_8_prob           | 0.0625                               |
# |    action_9_prob           | 0.109                                |
# |    avg_param_norm          | 1.563478                             |
# |    learning_rate           | <function create_optimized_ppo_mo... |
# |    obs_max                 | 10.0                                 |
# |    obs_mean                | 0.004073227                          |
# |    obs_min                 | -1.6418188                           |
# |    obs_std                 | 0.7482176                            |
# |    policy_first_layer_mean | -0.0008569016                        |
# |    policy_first_layer_norm | 0.58783126                           |
# |    policy_first_layer_std  | 0.03672946                           |
# |    rollout_reward_max      | 0.12219839                           |
# |    rollout_reward_mean     | -0.013079085                         |
# |    rollout_reward_min      | -1.0136219                           |
# |    rollout_reward_std      | 0.049889818                          |
# |    rollout_value_mean      | 0.00514168                           |
# |    rollout_value_std       | 0.03015058                           |
# |    total_policy_norm       | 9.830793                             |
# |    total_value_norm        | 10.494421                            |
# |    value_first_layer_mean  | -0.0014934631                        |
# |    value_first_layer_norm  | 0.5930288                            |
# |    value_first_layer_std   | 0.0370342                            |
# | env/                       |                                      |
# |    action_percentage       | -0.75                                |
# |    action_pov              | 0.0153                               |
# |    arrival_cost            | 7.32e-06                             |
# |    arrival_price           | 51.9                                 |
# |    holding_risk_cost       | 0.000608                             |
# |    order_vwap              | 52.8                                 |
# |    rate_penalty            | 1.87e-05                             |
# |    shares_remaining        | 46779                                |
# |    slippage_bps            | -163                                 |
# |    step_reward             | -0.000635                            |
# |    total_step_cost         | 0.000635                             |
# |    unfilled_cost           | 0                                    |
# |    vwap_cost               | 1.26e-06                             |
# | time/                      |                                      |
# |    fps                     | 4166                                 |
# |    iterations              | 1                                    |
# |    time_elapsed            | 31                                   |
# |    total_timesteps         | 131072                               |
# ---------------------------------------------------------------------
# ---------------------------------------------------------------------
# | custom/                    |                                      |
# |    action_0_prob           | 0.0781                               |
# |    action_10_prob          | 0.0312                               |
# |    action_1_prob           | 0.141                                |
# |    action_2_prob           | 0.109                                |
# |    action_3_prob           | 0.125                                |
# |    action_4_prob           | 0.0938                               |
# |    action_5_prob           | 0.0938                               |
# |    action_6_prob           | 0.0625                               |
# |    action_7_prob           | 0.109                                |
# |    action_8_prob           | 0.109                                |
# |    action_9_prob           | 0.0469                               |
# |    avg_param_norm          | 1.5695096                            |
# |    gradient_norm           | 0.0632                               |
# |    gradient_norm_per_param | 0.00486                              |
# |    learning_rate           | <function create_optimized_ppo_mo... |
# |    obs_max                 | 10.0                                 |
# |    obs_mean                | -0.0032976503                        |
# |    obs_min                 | -1.7036158                           |
# |    obs_std                 | 0.71945846                           |
# |    policy_first_layer_mean | -0.0011364348                        |
# |    policy_first_layer_norm | 0.5861494                            |
# |    policy_first_layer_std  | 0.036616705                          |
# |    rollout_reward_max      | 0.07289015                           |
# |    rollout_reward_mean     | -0.004007739                         |
# |    rollout_reward_min      | -0.037036218                         |
# |    rollout_reward_std      | 0.0017288091                         |
# |    rollout_value_mean      | -0.57412595                          |
# |    rollout_value_std       | 0.0932837                            |
# |    total_policy_norm       | 9.886724                             |
# |    total_value_norm        | 10.516902                            |
# |    value_first_layer_mean  | -0.0014239297                        |
# |    value_first_layer_norm  | 0.5965568                            |
# |    value_first_layer_std   | 0.0372576                            |
# | env/                       |                                      |
# |    action_percentage       | 1                                    |
# |    action_pov              | 0.0122                               |
# |    arrival_cost            | 0.000519                             |
# |    arrival_price           | 273                                  |
# |    holding_risk_cost       | 0.0002                               |
# |    order_vwap              | 275                                  |
# |    rate_penalty            | 2.44e-05                             |
# |    shares_remaining        | 166                                  |
# |    slippage_bps            | -61                                  |
# |    step_reward             | -0.000784                            |
# |    total_step_cost         | 0.000784                             |
# |    unfilled_cost           | 0                                    |
# |    vwap_cost               | 4.15e-05                             |
# | time/                      |                                      |
# |    fps                     | 4037                                 |
# |    iterations              | 2                                    |
# |    time_elapsed            | 64                                   |
# |    total_timesteps         | 262144                               |
# | train/                     |                                      |
# |    approx_kl               | 0.0051020747                         |
# |    clip_fraction           | 0.0198                               |
# |    clip_range              | 0.2                                  |
# |    clip_range_vf           | 0.2                                  |
# |    entropy_loss            | -2.39                                |
# |    explained_variance      | 0.00732                              |
# |    learning_rate           | 0.000292                             |
# |    loss                    | 0.0322                               |
# |    n_updates               | 3                                    |
# |    policy_gradient_loss    | -0.00114                             |
# |    value_loss              | 0.17                                 |
# ---------------------------------------------------------------------
# ---------------------------------------------------------------------
# | custom/                    |                                      |
# |    action_0_prob           | 0.0156                               |
# |    action_10_prob          | 0.0469                               |
# |    action_1_prob           | 0.0938                               |
# |    action_2_prob           | 0.0781                               |
# |    action_3_prob           | 0.141                                |
# |    action_4_prob           | 0.109                                |
# |    action_5_prob           | 0.125                                |
# |    action_6_prob           | 0.141                                |
# |    action_7_prob           | 0.0938                               |
# |    action_8_prob           | 0.0781                               |
# |    action_9_prob           | 0.0781                               |
# |    avg_param_norm          | 1.5742341                            |
# |    gradient_norm           | 0.0551                               |
# |    gradient_norm_per_param | 0.00424                              |
# |    learning_rate           | <function create_optimized_ppo_mo... |
# |    obs_max                 | 10.0                                 |
# |    obs_mean                | -0.011555119                         |
# |    obs_min                 | -1.722871                            |
# |    obs_std                 | 0.70108175                           |
# |    policy_first_layer_mean | -0.00118942                          |
# |    policy_first_layer_norm | 0.5856732                            |
# |    policy_first_layer_std  | 0.03658525                           |
# |    rollout_reward_max      | 0.022791067                          |
# |    rollout_reward_mean     | -0.0039646165                        |
# |    rollout_reward_min      | -0.021710364                         |
# |    rollout_reward_std      | 0.0018163443                         |
# |    rollout_value_mean      | -0.64398265                          |
# |    rollout_value_std       | 0.09192654                           |
# |    total_policy_norm       | 9.936612                             |
# |    total_value_norm        | 10.528432                            |
# |    value_first_layer_mean  | -0.0011930394                        |
# |    value_first_layer_norm  | 0.5967795                            |
# |    value_first_layer_std   | 0.037279636                          |
# | env/                       |                                      |
# |    action_percentage       | -0.1                                 |
# |    action_pov              | 0.0521                               |
# |    arrival_cost            | 1.41e-05                             |
# |    arrival_price           | 269                                  |
# |    holding_risk_cost       | 0.000788                             |
# |    order_vwap              | 269                                  |
# |    rate_penalty            | 4.6e-05                              |
# |    shares_remaining        | 9103                                 |
# |    slippage_bps            | 19.6                                 |
# |    step_reward             | -0.000849                            |
# |    total_step_cost         | 0.000849                             |
# |    unfilled_cost           | 0                                    |
# |    vwap_cost               | 2.86e-07                             |
# | time/                      |                                      |
# |    fps                     | 4008                                 |
# |    iterations              | 3                                    |
# |    time_elapsed            | 98                                   |
# |    total_timesteps         | 393216                               |
# | train/                     |                                      |
# |    approx_kl               | 0.0070858807                         |
# |    clip_fraction           | 0.0277                               |
# |    clip_range              | 0.2                                  |
# |    clip_range_vf           | 0.2                                  |
# |    entropy_loss            | -2.38                                |
# |    explained_variance      | 0.776                                |
# |    learning_rate           | 0.000283                             |
# |    loss                    | -0.0505                              |
# |    n_updates               | 6                                    |
# |    policy_gradient_loss    | -0.00256                             |
# |    value_loss              | 0.00134                              |
# ---------------------------------------------------------------------
# ---------------------------------------------------------------------
# | custom/                    |                                      |
# |    action_0_prob           | 0.0625                               |
# |    action_10_prob          | 0.156                                |
# |    action_1_prob           | 0.0625                               |
# |    action_2_prob           | 0.125                                |
# |    action_3_prob           | 0.0781                               |
# |    action_4_prob           | 0.125                                |
# |    action_5_prob           | 0.0625                               |
# |    action_6_prob           | 0.125                                |
# |    action_7_prob           | 0.0625                               |
# |    action_8_prob           | 0.0781                               |
# |    action_9_prob           | 0.0625                               |
# |    avg_param_norm          | 1.5805739                            |
# |    gradient_norm           | 0.081                                |
# |    gradient_norm_per_param | 0.00623                              |
# |    learning_rate           | <function create_optimized_ppo_mo... |
# |    obs_max                 | 10.0                                 |
# |    obs_mean                | 0.010507626                          |
# |    obs_min                 | -1.7454067                           |
# |    obs_std                 | 0.75594145                           |
# |    policy_first_layer_mean | -0.0012675795                        |
# |    policy_first_layer_norm | 0.5883912                            |
# |    policy_first_layer_std  | 0.036752596                          |
# |    rollout_reward_max      | 0.03819176                           |
# |    rollout_reward_mean     | -0.004353761                         |
# |    rollout_reward_min      | -0.037101276                         |
# |    rollout_reward_std      | 0.001964536                          |
# |    rollout_value_mean      | -0.7058993                           |
# |    rollout_value_std       | 0.09468329                           |
# |    total_policy_norm       | 9.988291                             |
# |    total_value_norm        | 10.55917                             |
# |    value_first_layer_mean  | -0.0008849943                        |
# |    value_first_layer_norm  | 0.59710133                           |
# |    value_first_layer_std   | 0.03730834                           |
# | env/                       |                                      |
# |    action_percentage       | 1                                    |
# |    action_pov              | 0.0521                               |
# |    arrival_cost            | 5.64e-05                             |
# |    arrival_price           | 31.3                                 |
# |    holding_risk_cost       | 0.000478                             |
# |    order_vwap              | 31.7                                 |
# |    rate_penalty            | 6.52e-05                             |
# |    shares_remaining        | 38463                                |
# |    slippage_bps            | -127                                 |
# |    step_reward             | -0.000599                            |
# |    total_step_cost         | 0.000599                             |
# |    unfilled_cost           | 0                                    |
# |    vwap_cost               | -1.17e-06                            |
# | time/                      |                                      |
# |    fps                     | 3959                                 |
# |    iterations              | 4                                    |
# |    time_elapsed            | 132                                  |
# |    total_timesteps         | 524288                               |
# | train/                     |                                      |
# |    approx_kl               | 0.005151376                          |
# |    clip_fraction           | 0.0142                               |
# |    clip_range              | 0.2                                  |
# |    clip_range_vf           | 0.2                                  |
# |    entropy_loss            | -2.38                                |
# |    explained_variance      | 0.835                                |
# |    learning_rate           | 0.000275                             |
# |    loss                    | -0.0482                              |
# |    n_updates               | 9                                    |
# |    policy_gradient_loss    | -0.0014                              |
# |    value_loss              | 0.0012                               |
# ---------------------------------------------------------------------
# ---------------------------------------------------------------------
# | custom/                    |                                      |
# |    action_0_prob           | 0.0625                               |
# |    action_10_prob          | 0.0781                               |
# |    action_1_prob           | 0.0625                               |
# |    action_2_prob           | 0.109                                |
# |    action_3_prob           | 0.0625                               |
# |    action_4_prob           | 0.0781                               |
# |    action_5_prob           | 0.0938                               |
# |    action_6_prob           | 0.0938                               |
# |    action_7_prob           | 0.125                                |
# |    action_8_prob           | 0.141                                |
# |    action_9_prob           | 0.0938                               |
# |    avg_param_norm          | 1.5887405                            |
# |    gradient_norm           | 0.068                                |
# |    gradient_norm_per_param | 0.00523                              |
# |    learning_rate           | <function create_optimized_ppo_mo... |
# |    obs_max                 | 10.0                                 |
# |    obs_mean                | -0.00045554418                       |
# |    obs_min                 | -1.7564012                           |
# |    obs_std                 | 0.7848866                            |
# |    policy_first_layer_mean | -0.0010385873                        |
# |    policy_first_layer_norm | 0.596637                             |
# |    policy_first_layer_std  | 0.037275348                          |
# |    rollout_reward_max      | 0.036964573                          |
# |    rollout_reward_mean     | -0.0047212876                        |
# |    rollout_reward_min      | -0.22647879                          |
# |    rollout_reward_std      | 0.0022474064                         |
# |    rollout_value_mean      | -0.78342885                          |
# |    rollout_value_std       | 0.09646712                           |
# |    total_policy_norm       | 10.0579815                           |
# |    total_value_norm        | 10.595644                            |
# |    value_first_layer_mean  | -0.00077287015                       |
# |    value_first_layer_norm  | 0.5986594                            |
# |    value_first_layer_std   | 0.03740823                           |
# | env/                       |                                      |
# |    action_percentage       | -0.1                                 |
# |    action_pov              | 0.0173                               |
# |    arrival_cost            | 1.82e-06                             |
# |    arrival_price           | 61.7                                 |
# |    holding_risk_cost       | 0.000843                             |
# |    order_vwap              | 61.7                                 |
# |    rate_penalty            | 1.28e-05                             |
# |    shares_remaining        | 1924                                 |
# |    slippage_bps            | -2.4                                 |
# |    step_reward             | -0.000858                            |
# |    total_step_cost         | 0.000858                             |
# |    unfilled_cost           | 0                                    |
# |    vwap_cost               | 6.45e-07                             |
# | time/                      |                                      |
# |    fps                     | 3926                                 |
# |    iterations              | 5                                    |
# |    time_elapsed            | 166                                  |
# |    total_timesteps         | 655360                               |
# | train/                     |                                      |
# |    approx_kl               | 0.0064224135                         |
# |    clip_fraction           | 0.0198                               |
# |    clip_range              | 0.2                                  |
# |    clip_range_vf           | 0.2                                  |
# |    entropy_loss            | -2.37                                |
# |    explained_variance      | 0.85                                 |
# |    learning_rate           | 0.000266                             |
# |    loss                    | -0.0505                              |
# |    n_updates               | 12                                   |
# |    policy_gradient_loss    | -0.00173                             |
# |    value_loss              | 0.00134                              |
# ---------------------------------------------------------------------
# ---------------------------------------------------------------------
# | custom/                    |                                      |
# |    action_0_prob           | 0.0938                               |
# |    action_10_prob          | 0.0781                               |
# |    action_1_prob           | 0.0312                               |
# |    action_2_prob           | 0.109                                |
# |    action_3_prob           | 0.0156                               |
# |    action_4_prob           | 0.109                                |
# |    action_5_prob           | 0.0938                               |
# |    action_6_prob           | 0.125                                |
# |    action_7_prob           | 0.0938                               |
# |    action_8_prob           | 0.109                                |
# |    action_9_prob           | 0.141                                |
# |    avg_param_norm          | 1.5959167                            |
# |    gradient_norm           | 0.0901                               |
# |    gradient_norm_per_param | 0.00693                              |
# |    learning_rate           | <function create_optimized_ppo_mo... |
# |    obs_max                 | 10.0                                 |
# |    obs_mean                | -0.026861904                         |
# |    obs_min                 | -1.7462156                           |
# |    obs_std                 | 0.70428073                           |
# |    policy_first_layer_mean | -0.00080142234                       |
# |    policy_first_layer_norm | 0.593999                             |
# |    policy_first_layer_std  | 0.03711629                           |
# |    rollout_reward_max      | 0.035223592                          |
# |    rollout_reward_mean     | -0.0049867826                        |
# |    rollout_reward_min      | -0.05171448                          |
# |    rollout_reward_std      | 0.0023880992                         |
# |    rollout_value_mean      | -0.85449827                          |
# |    rollout_value_std       | 0.09807825                           |
# |    total_policy_norm       | 10.113341                            |
# |    total_value_norm        | 10.633577                            |
# |    value_first_layer_mean  | -0.0005833035                        |
# |    value_first_layer_norm  | 0.59943455                           |
# |    value_first_layer_std   | 0.03746012                           |
# | env/                       |                                      |
# |    action_percentage       | 0.5                                  |
# |    action_pov              | 0.0394                               |
# |    arrival_cost            | -6.72e-05                            |
# |    arrival_price           | 47.7                                 |
# |    holding_risk_cost       | 0.000176                             |
# |    order_vwap              | 47.9                                 |
# |    rate_penalty            | 5.09e-05                             |
# |    shares_remaining        | 1281                                 |
# |    slippage_bps            | -36                                  |
# |    step_reward             | -0.00016                             |
# |    total_step_cost         | 0.00016                              |
# |    unfilled_cost           | 0                                    |
# |    vwap_cost               | -4.09e-07                            |
# | time/                      |                                      |
# |    fps                     | 3845                                 |
# |    iterations              | 6                                    |
# |    time_elapsed            | 204                                  |
# |    total_timesteps         | 786432                               |
# | train/                     |                                      |
# |    approx_kl               | 0.005579558                          |
# |    clip_fraction           | 0.0221                               |
# |    clip_range              | 0.2                                  |
# |    clip_range_vf           | 0.2                                  |
# |    entropy_loss            | -2.36                                |
# |    explained_variance      | 0.859                                |
# |    learning_rate           | 0.000258                             |
# |    loss                    | -0.0458                              |
# |    n_updates               | 15                                   |
# |    policy_gradient_loss    | -0.00172                             |
# |    value_loss              | 0.00144                              |
# ---------------------------------------------------------------------
# ---------------------------------------------------------------------
# | custom/                    |                                      |
# |    action_0_prob           | 0.0156                               |
# |    action_10_prob          | 0.141                                |
# |    action_1_prob           | 0.109                                |
# |    action_2_prob           | 0.0938                               |
# |    action_3_prob           | 0.0625                               |
# |    action_4_prob           | 0.0312                               |
# |    action_5_prob           | 0.109                                |
# |    action_6_prob           | 0.0781                               |
# |    action_7_prob           | 0.125                                |
# |    action_8_prob           | 0.109                                |
# |    action_9_prob           | 0.125                                |
# |    avg_param_norm          | 1.6021761                            |
# |    gradient_norm           | 0.0692                               |
# |    gradient_norm_per_param | 0.00532                              |
# |    learning_rate           | <function create_optimized_ppo_mo... |
# |    obs_max                 | 10.0                                 |
# |    obs_mean                | -0.018032508                         |
# |    obs_min                 | -1.7371004                           |
# |    obs_std                 | 0.7476509                            |
# |    policy_first_layer_mean | -0.0009983522                        |
# |    policy_first_layer_norm | 0.59571755                           |
# |    policy_first_layer_std  | 0.03721896                           |
# |    rollout_reward_max      | 0.025965117                          |
# |    rollout_reward_mean     | -0.0053080325                        |
# |    rollout_reward_min      | -0.04771359                          |
# |    rollout_reward_std      | 0.0025009718                         |
# |    rollout_value_mean      | -0.94401324                          |
# |    rollout_value_std       | 0.10494279                           |
# |    total_policy_norm       | 10.158261                            |
# |    total_value_norm        | 10.670027                            |
# |    value_first_layer_mean  | -0.00038394122                       |
# |    value_first_layer_norm  | 0.6007304                            |
# |    value_first_layer_std   | 0.03754369                           |
# | env/                       |                                      |
# |    action_percentage       | 0                                    |
# |    action_pov              | 0.0323                               |
# |    arrival_cost            | -1.01e-05                            |
# |    arrival_price           | 55.9                                 |
# |    holding_risk_cost       | 0.000578                             |
# |    order_vwap              | 55.7                                 |
# |    rate_penalty            | 6.52e-05                             |
# |    shares_remaining        | 122488                               |
# |    slippage_bps            | 43.1                                 |
# |    step_reward             | -0.000633                            |
# |    total_step_cost         | 0.000633                             |
# |    unfilled_cost           | 0                                    |
# |    vwap_cost               | -1.86e-08                            |
# | time/                      |                                      |
# |    fps                     | 3847                                 |
# |    iterations              | 7                                    |
# |    time_elapsed            | 238                                  |
# |    total_timesteps         | 917504                               |
# | train/                     |                                      |
# |    approx_kl               | 0.005333335                          |
# |    clip_fraction           | 0.016                                |
# |    clip_range              | 0.2                                  |
# |    clip_range_vf           | 0.2                                  |
# |    entropy_loss            | -2.36                                |
# |    explained_variance      | 0.866                                |
# |    learning_rate           | 0.00025                              |
# |    loss                    | -0.0486                              |
# |    n_updates               | 18                                   |
# |    policy_gradient_loss    | -0.00154                             |
# |    value_loss              | 0.00151                              |
# ---------------------------------------------------------------------
# ---------------------------------------------------------------------
# | custom/                    |                                      |
# |    action_0_prob           | 0.109                                |
# |    action_10_prob          | 0.141                                |
# |    action_1_prob           | 0.0781                               |
# |    action_2_prob           | 0.0625                               |
# |    action_3_prob           | 0.0781                               |
# |    action_4_prob           | 0.0938                               |
# |    action_5_prob           | 0.0781                               |
# |    action_6_prob           | 0.109                                |
# |    action_7_prob           | 0.0312                               |
# |    action_8_prob           | 0.141                                |
# |    action_9_prob           | 0.0781                               |
# |    avg_param_norm          | 1.609265                             |
# |    gradient_norm           | 0.0704                               |
# |    gradient_norm_per_param | 0.00541                              |
# |    learning_rate           | <function create_optimized_ppo_mo... |
# |    obs_max                 | 10.0                                 |
# |    obs_mean                | -0.012453493                         |
# |    obs_min                 | -1.720471                            |
# |    obs_std                 | 0.68554115                           |
# |    policy_first_layer_mean | -0.00086253055                       |
# |    policy_first_layer_norm | 0.5981496                            |
# |    policy_first_layer_std  | 0.037374396                          |
# |    rollout_reward_max      | 0.08555743                           |
# |    rollout_reward_mean     | -0.005589502                         |
# |    rollout_reward_min      | -0.15211777                          |
# |    rollout_reward_std      | 0.0027142467                         |
# |    rollout_value_mean      | -1.0244622                           |
# |    rollout_value_std       | 0.11070279                           |
# |    total_policy_norm       | 10.206301                            |
# |    total_value_norm        | 10.714143                            |
# |    value_first_layer_mean  | -0.000255386                         |
# |    value_first_layer_norm  | 0.6009097                            |
# |    value_first_layer_std   | 0.03755599                           |
# | env/                       |                                      |
# |    action_percentage       | 0                                    |
# |    action_pov              | 0.0282                               |
# |    arrival_cost            | 3.92e-05                             |
# |    arrival_price           | 151                                  |
# |    holding_risk_cost       | 6.46e-05                             |
# |    order_vwap              | 151                                  |
# |    rate_penalty            | 7.13e-05                             |
# |    shares_remaining        | 13146                                |
# |    slippage_bps            | 15.6                                 |
# |    step_reward             | -0.000172                            |
# |    total_step_cost         | 0.000172                             |
# |    unfilled_cost           | 0                                    |
# |    vwap_cost               | -2.65e-06                            |
# | time/                      |                                      |
# |    fps                     | 3854                                 |
# |    iterations              | 8                                    |
# |    time_elapsed            | 272                                  |
# |    total_timesteps         | 1048576                              |
# | train/                     |                                      |
# |    approx_kl               | 0.005314633                          |
# |    clip_fraction           | 0.0165                               |
# |    clip_range              | 0.2                                  |
# |    clip_range_vf           | 0.2                                  |
# |    entropy_loss            | -2.36                                |
# |    explained_variance      | 0.869                                |
# |    learning_rate           | 0.000241                             |
# |    loss                    | -0.0498                              |
# |    n_updates               | 21                                   |
# |    policy_gradient_loss    | -0.00152                             |
# |    value_loss              | 0.00173                              |
# ---------------------------------------------------------------------
# ---------------------------------------------------------------------
# | custom/                    |                                      |
# |    action_0_prob           | 0.0312                               |
# |    action_10_prob          | 0.109                                |
# |    action_1_prob           | 0.109                                |
# |    action_2_prob           | 0                                    |
# |    action_3_prob           | 0.125                                |
# |    action_4_prob           | 0.0938                               |
# |    action_5_prob           | 0.125                                |
# |    action_6_prob           | 0.0781                               |
# |    action_7_prob           | 0.0938                               |
# |    action_8_prob           | 0.156                                |
# |    action_9_prob           | 0.0781                               |
# |    avg_param_norm          | 1.6153251                            |
# |    gradient_norm           | 0.0911                               |
# |    gradient_norm_per_param | 0.00701                              |
# |    learning_rate           | <function create_optimized_ppo_mo... |
# |    obs_max                 | 10.0                                 |
# |    obs_mean                | -0.011032584                         |
# |    obs_min                 | -1.7262843                           |
# |    obs_std                 | 0.70105684                           |
# |    policy_first_layer_mean | -0.0010433493                        |
# |    policy_first_layer_norm | 0.5998059                            |
# |    policy_first_layer_std  | 0.03747335                           |
# |    rollout_reward_max      | 0.29741412                           |
# |    rollout_reward_mean     | -0.005856195                         |
# |    rollout_reward_min      | -0.20528637                          |
# |    rollout_reward_std      | 0.003015056                          |
# |    rollout_value_mean      | -1.1086705                           |
# |    rollout_value_std       | 0.10735282                           |
# |    total_policy_norm       | 10.246037                            |
# |    total_value_norm        | 10.753188                            |
# |    value_first_layer_mean  | -8.026627e-05                        |
# |    value_first_layer_norm  | 0.6028061                            |
# |    value_first_layer_std   | 0.037675295                          |
# | env/                       |                                      |
# |    action_percentage       | 0                                    |
# |    action_pov              | 0.0865                               |
# |    arrival_cost            | 9.29e-07                             |
# |    arrival_price           | 97.4                                 |
# |    holding_risk_cost       | 0.000503                             |
# |    order_vwap              | 97.4                                 |
# |    rate_penalty            | 8.84e-05                             |
# |    shares_remaining        | 23140                                |
# |    slippage_bps            | -1.46                                |
# |    step_reward             | -0.000592                            |
# |    total_step_cost         | 0.000592                             |
# |    unfilled_cost           | 0                                    |
# |    vwap_cost               | -1.42e-08                            |
# | time/                      |                                      |
# |    fps                     | 3863                                 |
# |    iterations              | 9                                    |
# |    time_elapsed            | 305                                  |
# |    total_timesteps         | 1179648                              |
# | train/                     |                                      |
# |    approx_kl               | 0.005081703                          |
# |    clip_fraction           | 0.0169                               |
# |    clip_range              | 0.2                                  |
# |    clip_range_vf           | 0.2                                  |
# |    entropy_loss            | -2.35                                |
# |    explained_variance      | 0.877                                |
# |    learning_rate           | 0.000233                             |
# |    loss                    | -0.05                                |
# |    n_updates               | 24                                   |
# |    policy_gradient_loss    | -0.00167                             |
# |    value_loss              | 0.00183                              |
# ---------------------------------------------------------------------
# ---------------------------------------------------------------------
# | custom/                    |                                      |
# |    action_0_prob           | 0.0156                               |
# |    action_10_prob          | 0.172                                |
# |    action_1_prob           | 0.0625                               |
# |    action_2_prob           | 0.0469                               |
# |    action_3_prob           | 0.109                                |
# |    action_4_prob           | 0.0938                               |
# |    action_5_prob           | 0.0938                               |
# |    action_6_prob           | 0.0469                               |
# |    action_7_prob           | 0.0781                               |
# |    action_8_prob           | 0.109                                |
# |    action_9_prob           | 0.172                                |
# |    avg_param_norm          | 1.6216196                            |
# |    gradient_norm           | 0.0867                               |
# |    gradient_norm_per_param | 0.00667                              |
# |    learning_rate           | <function create_optimized_ppo_mo... |
# |    obs_max                 | 10.0                                 |
# |    obs_mean                | -0.009465754                         |
# |    obs_min                 | -1.7299336                           |
# |    obs_std                 | 0.7121394                            |
# |    policy_first_layer_mean | -0.0010460422                        |
# |    policy_first_layer_norm | 0.6000852                            |
# |    policy_first_layer_std  | 0.037490733                          |
# |    rollout_reward_max      | 0.04610771                           |
# |    rollout_reward_mean     | -0.00613688                          |
# |    rollout_reward_min      | -0.040243022                         |
# |    rollout_reward_std      | 0.0029286898                         |
# |    rollout_value_mean      | -1.2098246                           |
# |    rollout_value_std       | 0.111359864                          |
# |    total_policy_norm       | 10.286863                            |
# |    total_value_norm        | 10.79419                             |
# |    value_first_layer_mean  | 4.752283e-05                         |
# |    value_first_layer_norm  | 0.60356706                           |
# |    value_first_layer_std   | 0.03772291                           |
# | env/                       |                                      |
# |    action_percentage       | -0.25                                |
# |    action_pov              | 0.00427                              |
# |    arrival_cost            | -1.81e-06                            |
# |    arrival_price           | 218                                  |
# |    holding_risk_cost       | 0.000695                             |
# |    order_vwap              | 219                                  |
# |    rate_penalty            | 7.66e-07                             |
# |    shares_remaining        | 1724                                 |
# |    slippage_bps            | -27.7                                |
# |    step_reward             | -0.000694                            |
# |    total_step_cost         | 0.000694                             |
# |    unfilled_cost           | 0                                    |
# |    vwap_cost               | 3.61e-08                             |
# | time/                      |                                      |
# |    fps                     | 3864                                 |
# |    iterations              | 10                                   |
# |    time_elapsed            | 339                                  |
# |    total_timesteps         | 1310720                              |
# | train/                     |                                      |
# |    approx_kl               | 0.005588252                          |
# |    clip_fraction           | 0.0165                               |
# |    clip_range              | 0.2                                  |
# |    clip_range_vf           | 0.2                                  |
# |    entropy_loss            | -2.34                                |
# |    explained_variance      | 0.873                                |
# |    learning_rate           | 0.000224                             |
# |    loss                    | -0.052                               |
# |    n_updates               | 27                                   |
# |    policy_gradient_loss    | -0.00183                             |
# |    value_loss              | 0.00183                              |
# ---------------------------------------------------------------------
# ---------------------------------------------------------------------
# | custom/                    |                                      |
# |    action_0_prob           | 0.125                                |
# |    action_10_prob          | 0.125                                |
# |    action_1_prob           | 0.109                                |
# |    action_2_prob           | 0.0312                               |
# |    action_3_prob           | 0.0938                               |
# |    action_4_prob           | 0.0156                               |
# |    action_5_prob           | 0.125                                |
# ...
# |    fps                     | 3863                                 |
# |    iterations              | 33                                   |
# |    time_elapsed            | 1119                                 |
# |    total_timesteps         | 4325376                              |
# | train/                     |                                      |
# |    approx_kl               | 0.0010057329                         |
# |    clip_fraction           | 0                                    |
# |    clip_range              | 0.2                                  |
# |    clip_range_vf           | 0.2                                  |
# |    entropy_loss            | -2.34                                |
# |    explained_variance      | 0.883                                |
# |    learning_rate           | 3.11e-05                             |
# |    loss                    | -0.0466                              |
# |    n_updates               | 96                                   |
# |    policy_gradient_loss    | -0.000454                            |
# |    value_loss              | 0.00391                              |
# ---------------------------------------------------------------------
# ---------------------------------------------------------------------
# | custom/                    |                                      |
# |    action_0_prob           | 0.0469                               |
# |    action_10_prob          | 0.0938                               |
# |    action_1_prob           | 0.0781                               |
# |    action_2_prob           | 0.0312                               |
# |    action_3_prob           | 0.188                                |
# |    action_4_prob           | 0.0938                               |
# |    action_5_prob           | 0.0625                               |
# |    action_6_prob           | 0.141                                |
# |    action_7_prob           | 0.109                                |
# |    action_8_prob           | 0.0625                               |
# |    action_9_prob           | 0.0938                               |
# |    avg_param_norm          | 1.7024096                            |
# |    gradient_norm           | 0.0846                               |
# |    gradient_norm_per_param | 0.00651                              |
# |    learning_rate           | <function create_optimized_ppo_mo... |
# |    obs_max                 | 10.0                                 |
# |    obs_mean                | -0.004852924                         |
# |    obs_min                 | -1.7291769                           |
# |    obs_std                 | 0.7259251                            |
# |    policy_first_layer_mean | -0.0027930199                        |
# |    policy_first_layer_norm | 0.591625                             |
# |    policy_first_layer_std  | 0.036870923                          |
# |    rollout_reward_max      | 0.48996806                           |
# |    rollout_reward_mean     | -0.0097230775                        |
# |    rollout_reward_min      | -0.13506326                          |
# |    rollout_reward_std      | 0.0049253968                         |
# |    rollout_value_mean      | -4.0763884                           |
# |    rollout_value_std       | 0.17660108                           |
# |    total_policy_norm       | 10.544378                            |
# |    total_value_norm        | 11.586946                            |
# |    value_first_layer_mean  | 0.0037151466                         |
# |    value_first_layer_norm  | 0.63544333                           |
# |    value_first_layer_std   | 0.039541062                          |
# | env/                       |                                      |
# |    action_percentage       | 0                                    |
# |    action_pov              | 0.0166                               |
# |    arrival_cost            | 2.34e-05                             |
# |    arrival_price           | 89.9                                 |
# |    holding_risk_cost       | 0                                    |
# |    order_vwap              | 89.9                                 |
# |    rate_penalty            | 0                                    |
# |    shares_remaining        | 0                                    |
# |    slippage_bps            | -8.35                                |
# |    step_reward             | -2.35e-05                            |
# |    total_step_cost         | 2.35e-05                             |
# |    unfilled_cost           | 0                                    |
# |    vwap_cost               | 9.12e-08                             |
# | time/                      |                                      |
# |    fps                     | 3864                                 |
# |    iterations              | 34                                   |
# |    time_elapsed            | 1153                                 |
# |    total_timesteps         | 4456448                              |
# | train/                     |                                      |
# |    approx_kl               | 0.00045361655                        |
# |    clip_fraction           | 0                                    |
# |    clip_range              | 0.2                                  |
# |    clip_range_vf           | 0.2                                  |
# |    entropy_loss            | -2.34                                |
# |    explained_variance      | 0.88                                 |
# |    learning_rate           | 2.27e-05                             |
# |    loss                    | -0.0451                              |
# |    n_updates               | 99                                   |
# |    policy_gradient_loss    | -0.000316                            |
# |    value_loss              | 0.00394                              |
# ---------------------------------------------------------------------
# ---------------------------------------------------------------------
# | custom/                    |                                      |
# |    action_0_prob           | 0.0312                               |
# |    action_10_prob          | 0.109                                |
# |    action_1_prob           | 0.0469                               |
# |    action_2_prob           | 0.0781                               |
# |    action_3_prob           | 0.0781                               |
# |    action_4_prob           | 0.0312                               |
# |    action_5_prob           | 0.0938                               |
# |    action_6_prob           | 0.125                                |
# |    action_7_prob           | 0.0938                               |
# |    action_8_prob           | 0.0938                               |
# |    action_9_prob           | 0.219                                |
# |    avg_param_norm          | 1.7031051                            |
# |    gradient_norm           | 0.0881                               |
# |    gradient_norm_per_param | 0.00678                              |
# |    learning_rate           | <function create_optimized_ppo_mo... |
# |    obs_max                 | 10.0                                 |
# |    obs_mean                | -0.013222224                         |
# |    obs_min                 | -1.7314905                           |
# |    obs_std                 | 0.67592067                           |
# |    policy_first_layer_mean | -0.0027412598                        |
# |    policy_first_layer_norm | 0.591656                             |
# |    policy_first_layer_std  | 0.036876757                          |
# |    rollout_reward_max      | 0.07006379                           |
# |    rollout_reward_mean     | -0.0097412625                        |
# |    rollout_reward_min      | -0.41786027                          |
# |    rollout_reward_std      | 0.004923355                          |
# |    rollout_value_mean      | -4.1898937                           |
# |    rollout_value_std       | 0.18644638                           |
# |    total_policy_norm       | 10.544379                            |
# |    total_value_norm        | 11.595986                            |
# |    value_first_layer_mean  | 0.003781766                          |
# |    value_first_layer_norm  | 0.63600284                           |
# |    value_first_layer_std   | 0.039569873                          |
# | env/                       |                                      |
# |    action_percentage       | 0.75                                 |
# |    action_pov              | 0.104                                |
# |    arrival_cost            | 1.01e-05                             |
# |    arrival_price           | 100                                  |
# |    holding_risk_cost       | 0.000889                             |
# |    order_vwap              | 99.9                                 |
# |    rate_penalty            | 2.05e-06                             |
# |    shares_remaining        | 14038                                |
# |    slippage_bps            | 40.6                                 |
# |    step_reward             | -0.000902                            |
# |    total_step_cost         | 0.000902                             |
# |    unfilled_cost           | 0                                    |
# |    vwap_cost               | 3.56e-07                             |
# | time/                      |                                      |
# |    fps                     | 3862                                 |
# |    iterations              | 35                                   |
# |    time_elapsed            | 1187                                 |
# |    total_timesteps         | 4587520                              |
# | train/                     |                                      |
# |    approx_kl               | 0.00015099802                        |
# |    clip_fraction           | 0                                    |
# |    clip_range              | 0.2                                  |
# |    clip_range_vf           | 0.2                                  |
# |    entropy_loss            | -2.34                                |
# |    explained_variance      | 0.893                                |
# |    learning_rate           | 1.43e-05                             |
# |    loss                    | -0.045                               |
# |    n_updates               | 102                                  |
# |    policy_gradient_loss    | -0.00022                             |
# |    value_loss              | 0.0042                               |
# ---------------------------------------------------------------------
# ---------------------------------------------------------------------
# | custom/                    |                                      |
# |    action_0_prob           | 0.0781                               |
# |    action_10_prob          | 0.156                                |
# |    action_1_prob           | 0.0156                               |
# |    action_2_prob           | 0.0469                               |
# |    action_3_prob           | 0.0781                               |
# |    action_4_prob           | 0                                    |
# |    action_5_prob           | 0.0781                               |
# |    action_6_prob           | 0.0781                               |
# |    action_7_prob           | 0.0781                               |
# |    action_8_prob           | 0.172                                |
# |    action_9_prob           | 0.219                                |
# |    avg_param_norm          | 1.7036661                            |
# |    gradient_norm           | 0.105                                |
# |    gradient_norm_per_param | 0.00805                              |
# |    learning_rate           | <function create_optimized_ppo_mo... |
# |    obs_max                 | 10.0                                 |
# |    obs_mean                | -0.017138671                         |
# |    obs_min                 | -1.7250714                           |
# |    obs_std                 | 0.7028616                            |
# |    policy_first_layer_mean | -0.0027656623                        |
# |    policy_first_layer_norm | 0.59160596                           |
# |    policy_first_layer_std  | 0.036871795                          |
# |    rollout_reward_max      | 0.057751063                          |
# |    rollout_reward_mean     | -0.009872239                         |
# |    rollout_reward_min      | -0.22415651                          |
# |    rollout_reward_std      | 0.0048058094                         |
# |    rollout_value_mean      | -4.2970552                           |
# |    rollout_value_std       | 0.17590614                           |
# |    total_policy_norm       | 10.543779                            |
# |    total_value_norm        | 11.60388                             |
# |    value_first_layer_mean  | 0.003847267                          |
# |    value_first_layer_norm  | 0.63676244                           |
# |    value_first_layer_std   | 0.039611258                          |
# | env/                       |                                      |
# |    action_percentage       | 0.5                                  |
# |    action_pov              | 0.0345                               |
# |    arrival_cost            | -2.76e-05                            |
# |    arrival_price           | 41.6                                 |
# |    holding_risk_cost       | 0.000391                             |
# |    order_vwap              | 41.7                                 |
# |    rate_penalty            | 2.41e-05                             |
# |    shares_remaining        | 3263                                 |
# |    slippage_bps            | -12.8                                |
# |    step_reward             | -0.000386                            |
# |    total_step_cost         | 0.000386                             |
# |    unfilled_cost           | 0                                    |
# |    vwap_cost               | -9.56e-07                            |
# | time/                      |                                      |
# |    fps                     | 3863                                 |
# |    iterations              | 36                                   |
# |    time_elapsed            | 1221                                 |
# |    total_timesteps         | 4718592                              |
# | train/                     |                                      |
# |    approx_kl               | 2.7572012e-05                        |
# |    clip_fraction           | 0                                    |
# |    clip_range              | 0.2                                  |
# |    clip_range_vf           | 0.2                                  |
# |    entropy_loss            | -2.34                                |
# |    explained_variance      | 0.891                                |
# |    learning_rate           | 5.93e-06                             |
# |    loss                    | -0.0446                              |
# |    n_updates               | 105                                  |
# |    policy_gradient_loss    | -6.97e-05                            |
# |    value_loss              | 0.00485                              |
# ---------------------------------------------------------------------
# 2025-08-28 20:58:03 - root - INFO -
# ============================================================
# 2025-08-28 20:58:03 - root - INFO - TRAINING COMPLETED: ppo_multiorder_exec_vec
# 2025-08-28 20:58:03 - root - INFO - ============================================================
# 2025-08-28 20:58:03 - root - INFO -   Total training time: 1224.56 seconds
# 2025-08-28 20:58:03 - root - INFO -   Total timesteps: 4,680,000.0
# 2025-08-28 20:58:03 - root - INFO -   Performance: 3821.8 steps/second
# 2025-08-28 20:58:03 - root - INFO -   Time per 1000 steps: 0.26 seconds
# 2025-08-28 20:58:03 - root - INFO -   Expected remaining time for 1M steps: -16.0 minutes
# (<stable_baselines3.ppo.ppo.PPO at 0x70e85ae77c20>, 1224.5639169216156)

# %%
# Add baseline strategies
baseline_strategies = []
print("\nSetting up baseline strategies...")
vwap_model = bs.VWAPBaseline()
mp_vec.park_model(vwap_model, "vwap_baseline_vec", learn=False, save=False)
baseline_strategies.append("vwap_baseline_vec")
random_model = bs.RandomBaseline(seed=fixed_seed)
mp_vec.park_model(random_model, "random_baseline_vec", learn=False, save=False)
baseline_strategies.append("random_baseline_vec")
print(f"Baseline models saved")
# Out:
# Setting up baseline strategies...
# 2025-08-28 20:58:03 - baseline_strategies - INFO - Initialized VWAP_Baseline strategy
# 2025-08-28 20:58:03 - baseline_strategies - INFO - Initialized Random_Baseline strategy
# Baseline models saved

# %%
model_name = "ppo_cnn_multiorder_exec_vec_cpu"

class ExecCNNExtractor(BaseFeaturesExtractor):
    """
    CNN-based feature extractor for execution states.

    Suitable when the state is represented as a structured 2D tensor
    (e.g. [channels x timesteps] for stacked time series of prices, spreads, volumes).
    """
    def __init__(self, observation_space, features_dim=256):
        super().__init__(observation_space, features_dim)

        n_input_channels = observation_space.shape[0]

        # CNN backbone
        self.cnn = nn.Sequential(
            nn.Conv1d(n_input_channels, 32, kernel_size=3, stride=1, padding=1),
            nn.ReLU(),
            nn.Conv1d(32, 64, kernel_size=3, stride=1, padding=1),
            nn.ReLU(),
            nn.MaxPool1d(kernel_size=2, stride=2),  # downsample time dimension

            nn.Conv1d(64, 128, kernel_size=3, stride=1, padding=1),
            nn.ReLU(),
            nn.AdaptiveAvgPool1d(1),  # global pooling over time
        )

        # Linear projection to features_dim
        self.fc = nn.Sequential(
            nn.Flatten(),
            nn.Linear(128, features_dim),
            nn.ReLU()
        )

        self._features_dim = features_dim

    def forward(self, obs: torch.Tensor) -> torch.Tensor:
        # Expect obs: [batch_size, channels, timesteps]
        x = self.cnn(obs)
        return self.fc(x)


po.train_ppo_fast(train_execution_cpu_env, model_name=model_name, num_train_steps=num_train_steps,
                    mp_vec=mp_vec, feature_extractor=ExecCNNExtractor, callbacks=callbacks, 
                    device="cpu", ppo_gamma=PPO_GAMMA)
# Out:
# ============================================================
# OPTIMIZED PPO TRAINING: ppo_cnn_multiorder_exec_vec_cpu
# ============================================================
# Using cpu device
# 2025-08-28 20:58:03 - root - INFO -
# Optimized Training Configuration for ppo_cnn_multiorder_exec_vec_cpu_nsteps_2048_batchsize_8192_epochs_3:
# 2025-08-28 20:58:03 - root - INFO -   - Parallel environments: 64
# 2025-08-28 20:58:03 - root - INFO -   - Steps per rollout: 2048
# 2025-08-28 20:58:03 - root - INFO -   - Total samples per rollout: 131,072
# 2025-08-28 20:58:03 - root - INFO -   - Batch size: 8,192
# 2025-08-28 20:58:03 - root - INFO -   - Mini-batches per epoch: 16
# 2025-08-28 20:58:03 - root - INFO -   - Epochs per update: 3
# 2025-08-28 20:58:03 - root - INFO -   - Approximate updates per second: 20.8
# optimizer lr at init: 0.0003
#
# Training ppo_cnn_multiorder_exec_vec_cpu_nsteps_2048_batchsize_8192_epochs_3 for 4,680,000.0 timesteps...
# Using 16 CPU threads for training
# Logging to ./tensorboard_logs/ppo_cnn_multiorder_exec_vec_cpu_nsteps_2048_batchsize_8192_epochs_3/PPO_4
# ---------------------------------------------------------------------
# | custom/                    |                                      |
# |    action_0_prob           | 0.125                                |
# |    action_10_prob          | 0.0938                               |
# |    action_1_prob           | 0.0938                               |
# |    action_2_prob           | 0.0938                               |
# |    action_3_prob           | 0.156                                |
# |    action_4_prob           | 0.0625                               |
# |    action_5_prob           | 0.0938                               |
# |    action_6_prob           | 0.0781                               |
# |    action_7_prob           | 0.0781                               |
# |    action_8_prob           | 0.0781                               |
# |    action_9_prob           | 0.0469                               |
# |    avg_param_norm          | 1.5570335                            |
# |    learning_rate           | <function create_optimized_ppo_mo... |
# |    obs_max                 | 10.0                                 |
# |    obs_mean                | -0.022266906                         |
# |    obs_min                 | -1.7303667                           |
# |    obs_std                 | 0.707904                             |
# |    policy_first_layer_mean | -0.0048693903                        |
# |    policy_first_layer_norm | 0.59990853                           |
# |    policy_first_layer_std  | 0.037176743                          |
# |    rollout_reward_max      | 0.06876907                           |
# |    rollout_reward_mean     | -0.009005627                         |
# |    rollout_reward_min      | -0.08669424                          |
# |    rollout_reward_std      | 0.0040061106                         |
# |    rollout_value_mean      | -0.029530484                         |
# |    rollout_value_std       | 0.04316218                           |
# |    total_policy_norm       | 9.82335                              |
# |    total_value_norm        | 10.418087                            |
# |    value_first_layer_mean  | -0.00067233935                       |
# |    value_first_layer_norm  | 0.58164597                           |
# |    value_first_layer_std   | 0.036346655                          |
# | env/                       |                                      |
# |    action_percentage       | -0.1                                 |
# |    action_pov              | 0.006                                |
# |    arrival_cost            | -3.21e-06                            |
# |    arrival_price           | 192                                  |
# |    holding_risk_cost       | 6.12e-06                             |
# |    order_vwap              | 192                                  |
# |    rate_penalty            | 3.54e-05                             |
# |    shares_remaining        | 141                                  |
# |    slippage_bps            | -7.74                                |
# |    step_reward             | -3.87e-05                            |
# |    total_step_cost         | 3.87e-05                             |
# |    unfilled_cost           | 0                                    |
# |    vwap_cost               | 3.37e-07                             |
# | time/                      |                                      |
# |    fps                     | 4029                                 |
# |    iterations              | 1                                    |
# |    time_elapsed            | 32                                   |
# |    total_timesteps         | 131072                               |
# ---------------------------------------------------------------------
# ---------------------------------------------------------------------
# | custom/                    |                                      |
# |    action_0_prob           | 0.109                                |
# |    action_10_prob          | 0.0625                               |
# |    action_1_prob           | 0.0469                               |
# |    action_2_prob           | 0.0312                               |
# |    action_3_prob           | 0.188                                |
# |    action_4_prob           | 0.141                                |
# |    action_5_prob           | 0.0625                               |
# |    action_6_prob           | 0.0156                               |
# |    action_7_prob           | 0.172                                |
# |    action_8_prob           | 0.0781                               |
# |    action_9_prob           | 0.0938                               |
# |    avg_param_norm          | 1.5627383                            |
# |    gradient_norm           | 0.0772                               |
# |    gradient_norm_per_param | 0.00594                              |
# |    learning_rate           | <function create_optimized_ppo_mo... |
# |    obs_max                 | 10.0                                 |
# |    obs_mean                | -0.008926493                         |
# |    obs_min                 | -1.7272574                           |
# |    obs_std                 | 0.80038804                           |
# |    policy_first_layer_mean | -0.0049580107                        |
# |    policy_first_layer_norm | 0.60144323                           |
# |    policy_first_layer_std  | 0.037261795                          |
# |    rollout_reward_max      | 0.04866482                           |
# |    rollout_reward_mean     | -0.0084654                           |
# |    rollout_reward_min      | -0.4119025                           |
# |    rollout_reward_std      | 0.0040410305                         |
# |    rollout_value_mean      | -0.6035956                           |
# |    rollout_value_std       | 0.044440288                          |
# |    total_policy_norm       | 9.87753                              |
# |    total_value_norm        | 10.438068                            |
# |    value_first_layer_mean  | -0.0005326603                        |
# |    value_first_layer_norm  | 0.5840154                            |
# |    value_first_layer_std   | 0.03649708                           |
# | env/                       |                                      |
# |    action_percentage       | -0.1                                 |
# |    action_pov              | 0.0783                               |
# |    arrival_cost            | -6.66e-06                            |
# |    arrival_price           | 95                                   |
# |    holding_risk_cost       | 0.000881                             |
# |    order_vwap              | 95.3                                 |
# |    rate_penalty            | 1.06e-05                             |
# |    shares_remaining        | 50871                                |
# |    slippage_bps            | -30.4                                |
# |    step_reward             | -0.000886                            |
# |    total_step_cost         | 0.000886                             |
# |    unfilled_cost           | 0                                    |
# |    vwap_cost               | 9.03e-07                             |
# | time/                      |                                      |
# |    fps                     | 3939                                 |
# |    iterations              | 2                                    |
# |    time_elapsed            | 66                                   |
# |    total_timesteps         | 262144                               |
# | train/                     |                                      |
# |    approx_kl               | 0.006983255                          |
# |    clip_fraction           | 0.025                                |
# |    clip_range              | 0.2                                  |
# |    clip_range_vf           | 0.2                                  |
# |    entropy_loss            | -2.39                                |
# |    explained_variance      | 0.206                                |
# |    learning_rate           | 0.000292                             |
# |    loss                    | -0.0471                              |
# |    n_updates               | 3                                    |
# |    policy_gradient_loss    | -0.0018                              |
# |    value_loss              | 0.00492                              |
# ---------------------------------------------------------------------
# ---------------------------------------------------------------------
# | custom/                    |                                      |
# |    action_0_prob           | 0.0156                               |
# |    action_10_prob          | 0.109                                |
# |    action_1_prob           | 0.0625                               |
# |    action_2_prob           | 0.0625                               |
# |    action_3_prob           | 0.109                                |
# |    action_4_prob           | 0.0938                               |
# |    action_5_prob           | 0.0938                               |
# |    action_6_prob           | 0.172                                |
# |    action_7_prob           | 0.0312                               |
# |    action_8_prob           | 0.0781                               |
# |    action_9_prob           | 0.172                                |
# |    avg_param_norm          | 1.5728557                            |
# |    gradient_norm           | 0.0754                               |
# |    gradient_norm_per_param | 0.0058                               |
# |    learning_rate           | <function create_optimized_ppo_mo... |
# |    obs_max                 | 10.0                                 |
# |    obs_mean                | 0.008534544                          |
# |    obs_min                 | -1.7209623                           |
# |    obs_std                 | 0.7681973                            |
# |    policy_first_layer_mean | -0.0051493566                        |
# |    policy_first_layer_norm | 0.6019493                            |
# |    policy_first_layer_std  | 0.037267763                          |
# |    rollout_reward_max      | 0.06531205                           |
# |    rollout_reward_mean     | -0.008256744                         |
# |    rollout_reward_min      | -0.08257324                          |
# |    rollout_reward_std      | 0.0038899009                         |
# |    rollout_value_mean      | -1.6947755                           |
# |    rollout_value_std       | 0.13798569                           |
# |    total_policy_norm       | 9.9249115                            |
# |    total_value_norm        | 10.522214                            |
# |    value_first_layer_mean  | 0.00089265977                        |
# |    value_first_layer_norm  | 0.5876315                            |
# |    value_first_layer_std   | 0.036716122                          |
# | env/                       |                                      |
# |    action_percentage       | 0.75                                 |
# |    action_pov              | 0.303                                |
# |    arrival_cost            | -1.26e-05                            |
# |    arrival_price           | 355                                  |
# |    holding_risk_cost       | 0.000771                             |
# |    order_vwap              | 354                                  |
# |    rate_penalty            | 7.99e-05                             |
# |    shares_remaining        | 15934                                |
# |    slippage_bps            | 22.7                                 |
# |    step_reward             | -0.000841                            |
# |    total_step_cost         | 0.000841                             |
# |    unfilled_cost           | 0                                    |
# |    vwap_cost               | 3.11e-06                             |
# | time/                      |                                      |
# |    fps                     | 3898                                 |
# |    iterations              | 3                                    |
# |    time_elapsed            | 100                                  |
# |    total_timesteps         | 393216                               |
# | train/                     |                                      |
# |    approx_kl               | 0.005512663                          |
# |    clip_fraction           | 0.0167                               |
# |    clip_range              | 0.2                                  |
# |    clip_range_vf           | 0.2                                  |
# |    entropy_loss            | -2.38                                |
# |    explained_variance      | 0.381                                |
# |    learning_rate           | 0.000283                             |
# |    loss                    | -0.0421                              |
# |    n_updates               | 6                                    |
# |    policy_gradient_loss    | -0.00121                             |
# |    value_loss              | 0.00607                              |
# ---------------------------------------------------------------------
# ---------------------------------------------------------------------
# | custom/                    |                                      |
# |    action_0_prob           | 0.172                                |
# |    action_10_prob          | 0.141                                |
# |    action_1_prob           | 0.0625                               |
# |    action_2_prob           | 0.0469                               |
# |    action_3_prob           | 0.109                                |
# |    action_4_prob           | 0.0625                               |
# |    action_5_prob           | 0.0938                               |
# |    action_6_prob           | 0.0781                               |
# |    action_7_prob           | 0.0781                               |
# |    action_8_prob           | 0.0781                               |
# |    action_9_prob           | 0.0781                               |
# |    avg_param_norm          | 1.5839832                            |
# |    gradient_norm           | 0.0771                               |
# |    gradient_norm_per_param | 0.00593                              |
# |    learning_rate           | <function create_optimized_ppo_mo... |
# |    obs_max                 | 10.0                                 |
# |    obs_mean                | 0.019887708                          |
# |    obs_min                 | -1.727512                            |
# |    obs_std                 | 0.8104419                            |
# |    policy_first_layer_mean | -0.0053373855                        |
# |    policy_first_layer_norm | 0.600374                             |
# |    policy_first_layer_std  | 0.037141833                          |
# |    rollout_reward_max      | 0.051703118                          |
# |    rollout_reward_mean     | -0.00830483                          |
# |    rollout_reward_min      | -0.082395785                         |
# |    rollout_reward_std      | 0.0038739445                         |
# |    rollout_value_mean      | -3.0926611                           |
# |    rollout_value_std       | 0.26000828                           |
# |    total_policy_norm       | 9.966591                             |
# |    total_value_norm        | 10.62519                             |
# |    value_first_layer_mean  | 0.0023773653                         |
# |    value_first_layer_norm  | 0.59237343                           |
# |    value_first_layer_std   | 0.036946934                          |
# | env/                       |                                      |
# |    action_percentage       | 0.25                                 |
# |    action_pov              | 0.101                                |
# |    arrival_cost            | 1.75e-05                             |
# |    arrival_price           | 89.4                                 |
# |    holding_risk_cost       | 0.000882                             |
# |    order_vwap              | 89.4                                 |
# |    rate_penalty            | 1.77e-05                             |
# |    shares_remaining        | 27191                                |
# |    slippage_bps            | -0.174                               |
# |    step_reward             | -0.000916                            |
# |    total_step_cost         | 0.000916                             |
# |    unfilled_cost           | 0                                    |
# |    vwap_cost               | -5.7e-07                             |
# | time/                      |                                      |
# |    fps                     | 3888                                 |
# |    iterations              | 4                                    |
# |    time_elapsed            | 134                                  |
# |    total_timesteps         | 524288                               |
# | train/                     |                                      |
# |    approx_kl               | 0.005906388                          |
# |    clip_fraction           | 0.0246                               |
# |    clip_range              | 0.2                                  |
# |    clip_range_vf           | 0.2                                  |
# |    entropy_loss            | -2.37                                |
# |    explained_variance      | 0.711                                |
# |    learning_rate           | 0.000275                             |
# |    loss                    | -0.0407                              |
# |    n_updates               | 9                                    |
# |    policy_gradient_loss    | -0.00176                             |
# |    value_loss              | 0.0126                               |
# ---------------------------------------------------------------------
# ---------------------------------------------------------------------
# | custom/                    |                                      |
# |    action_0_prob           | 0.0625                               |
# |    action_10_prob          | 0.0938                               |
# |    action_1_prob           | 0.109                                |
# |    action_2_prob           | 0.0312                               |
# |    action_3_prob           | 0.141                                |
# |    action_4_prob           | 0.0781                               |
# |    action_5_prob           | 0.0469                               |
# |    action_6_prob           | 0.0625                               |
# |    action_7_prob           | 0.0938                               |
# |    action_8_prob           | 0.172                                |
# |    action_9_prob           | 0.109                                |
# |    avg_param_norm          | 1.5893147                            |
# |    gradient_norm           | 0.0844                               |
# |    gradient_norm_per_param | 0.00649                              |
# |    learning_rate           | <function create_optimized_ppo_mo... |
# |    obs_max                 | 10.0                                 |
# |    obs_mean                | -0.012742918                         |
# |    obs_min                 | -1.7274616                           |
# |    obs_std                 | 0.67241544                           |
# |    policy_first_layer_mean | -0.0057138246                        |
# |    policy_first_layer_norm | 0.60168165                           |
# |    policy_first_layer_std  | 0.03716848                           |
# |    rollout_reward_max      | 0.06725544                           |
# |    rollout_reward_mean     | -0.008387042                         |
# |    rollout_reward_min      | -0.10016092                          |
# |    rollout_reward_std      | 0.0039293435                         |
# |    rollout_value_mean      | -3.1861093                           |
# |    rollout_value_std       | 0.2559844                            |
# |    total_policy_norm       | 9.999773                             |
# |    total_value_norm        | 10.661317                            |
# |    value_first_layer_mean  | 0.002810183                          |
# |    value_first_layer_norm  | 0.5931934                            |
# |    value_first_layer_std   | 0.036967933                          |
# | env/                       |                                      |
# |    action_percentage       | 0.5                                  |
# |    action_pov              | 0.0524                               |
# |    arrival_cost            | -5.6e-05                             |
# |    arrival_price           | 93.6                                 |
# |    holding_risk_cost       | 8.51e-05                             |
# |    order_vwap              | 95                                   |
# |    rate_penalty            | 5.8e-05                              |
# |    shares_remaining        | 4439                                 |
# |    slippage_bps            | -147                                 |
# |    step_reward             | -8.67e-05                            |
# |    total_step_cost         | 8.67e-05                             |
# |    unfilled_cost           | 0                                    |
# |    vwap_cost               | -4.17e-07                            |
# | time/                      |                                      |
# |    fps                     | 3859                                 |
# |    iterations              | 5                                    |
# |    time_elapsed            | 169                                  |
# |    total_timesteps         | 655360                               |
# | train/                     |                                      |
# |    approx_kl               | 0.0062500713                         |
# |    clip_fraction           | 0.0255                               |
# |    clip_range              | 0.2                                  |
# |    clip_range_vf           | 0.2                                  |
# |    entropy_loss            | -2.36                                |
# |    explained_variance      | 0.76                                 |
# |    learning_rate           | 0.000266                             |
# |    loss                    | -0.0458                              |
# |    n_updates               | 12                                   |
# |    policy_gradient_loss    | -0.00133                             |
# |    value_loss              | 0.00996                              |
# ---------------------------------------------------------------------
# ---------------------------------------------------------------------
# | custom/                    |                                      |
# |    action_0_prob           | 0.0938                               |
# |    action_10_prob          | 0.0312                               |
# |    action_1_prob           | 0.0781                               |
# |    action_2_prob           | 0.0469                               |
# |    action_3_prob           | 0.0938                               |
# |    action_4_prob           | 0.0938                               |
# |    action_5_prob           | 0.141                                |
# |    action_6_prob           | 0.0625                               |
# |    action_7_prob           | 0.219                                |
# |    action_8_prob           | 0.0625                               |
# |    action_9_prob           | 0.0781                               |
# |    avg_param_norm          | 1.5952433                            |
# |    gradient_norm           | 0.0722                               |
# |    gradient_norm_per_param | 0.00555                              |
# |    learning_rate           | <function create_optimized_ppo_mo... |
# |    obs_max                 | 10.0                                 |
# |    obs_mean                | -0.008579406                         |
# |    obs_min                 | -1.7271761                           |
# |    obs_std                 | 0.7482873                            |
# |    policy_first_layer_mean | -0.0058563785                        |
# |    policy_first_layer_norm | 0.6007118                            |
# |    policy_first_layer_std  | 0.037084922                          |
# |    rollout_reward_max      | 0.047705963                          |
# |    rollout_reward_mean     | -0.008413803                         |
# |    rollout_reward_min      | -0.06199652                          |
# |    rollout_reward_std      | 0.0040230034                         |
# |    rollout_value_mean      | -3.2848186                           |
# |    rollout_value_std       | 0.25777853                           |
# |    total_policy_norm       | 10.031119                            |
# |    total_value_norm        | 10.707045                            |
# |    value_first_layer_mean  | 0.003121465                          |
# |    value_first_layer_norm  | 0.59497046                           |
# |    value_first_layer_std   | 0.03705441                           |
# | env/                       |                                      |
# |    action_percentage       | 0.75                                 |
# |    action_pov              | 0.0984                               |
# |    arrival_cost            | 1.34e-05                             |
# |    arrival_price           | 130                                  |
# |    holding_risk_cost       | 0.000703                             |
# |    order_vwap              | 129                                  |
# |    rate_penalty            | 1.18e-05                             |
# |    shares_remaining        | 8779                                 |
# |    slippage_bps            | 61.1                                 |
# |    step_reward             | -0.000728                            |
# |    total_step_cost         | 0.000728                             |
# |    unfilled_cost           | 0                                    |
# |    vwap_cost               | 3.23e-07                             |
# | time/                      |                                      |
# |    fps                     | 3838                                 |
# |    iterations              | 6                                    |
# |    time_elapsed            | 204                                  |
# |    total_timesteps         | 786432                               |
# | train/                     |                                      |
# |    approx_kl               | 0.007189636                          |
# |    clip_fraction           | 0.0337                               |
# |    clip_range              | 0.2                                  |
# |    clip_range_vf           | 0.2                                  |
# |    entropy_loss            | -2.37                                |
# |    explained_variance      | 0.833                                |
# |    learning_rate           | 0.000258                             |
# |    loss                    | -0.0487                              |
# |    n_updates               | 15                                   |
# |    policy_gradient_loss    | -0.00147                             |
# |    value_loss              | 0.00719                              |
# ---------------------------------------------------------------------
# ---------------------------------------------------------------------
# | custom/                    |                                      |
# |    action_0_prob           | 0.0625                               |
# |    action_10_prob          | 0.0625                               |
# |    action_1_prob           | 0.0469                               |
# |    action_2_prob           | 0.0625                               |
# |    action_3_prob           | 0.0625                               |
# |    action_4_prob           | 0.0469                               |
# |    action_5_prob           | 0.0469                               |
# |    action_6_prob           | 0.0938                               |
# |    action_7_prob           | 0.219                                |
# |    action_8_prob           | 0.141                                |
# |    action_9_prob           | 0.156                                |
# |    avg_param_norm          | 1.6010015                            |
# |    gradient_norm           | 0.099                                |
# |    gradient_norm_per_param | 0.00762                              |
# |    learning_rate           | <function create_optimized_ppo_mo... |
# |    obs_max                 | 10.0                                 |
# |    obs_mean                | -0.018790841                         |
# |    obs_min                 | -1.7217821                           |
# |    obs_std                 | 0.7509696                            |
# |    policy_first_layer_mean | -0.0059186853                        |
# |    policy_first_layer_norm | 0.6024277                            |
# |    policy_first_layer_std  | 0.037183627                          |
# |    rollout_reward_max      | 0.086699136                          |
# |    rollout_reward_mean     | -0.008435111                         |
# |    rollout_reward_min      | -0.08609467                          |
# |    rollout_reward_std      | 0.004056995                          |
# |    rollout_value_mean      | -3.4101243                           |
# |    rollout_value_std       | 0.25603682                           |
# |    total_policy_norm       | 10.063823                            |
# |    total_value_norm        | 10.749197                            |
# |    value_first_layer_mean  | 0.0032947222                         |
# |    value_first_layer_norm  | 0.59662515                           |
# |    value_first_layer_std   | 0.03714323                           |
# | env/                       |                                      |
# |    action_percentage       | 0.25                                 |
# |    action_pov              | 0.108                                |
# |    arrival_cost            | -0.000437                            |
# |    arrival_price           | 295                                  |
# |    holding_risk_cost       | 8.57e-05                             |
# |    order_vwap              | 292                                  |
# |    rate_penalty            | 2.43e-05                             |
# |    shares_remaining        | 370                                  |
# |    slippage_bps            | 98.3                                 |
# |    step_reward             | 0.000355                             |
# |    total_step_cost         | -0.000355                            |
# |    unfilled_cost           | 0                                    |
# |    vwap_cost               | -2.78e-05                            |
# | time/                      |                                      |
# |    fps                     | 3838                                 |
# |    iterations              | 7                                    |
# |    time_elapsed            | 239                                  |
# |    total_timesteps         | 917504                               |
# | train/                     |                                      |
# |    approx_kl               | 0.0069707753                         |
# |    clip_fraction           | 0.029                                |
# |    clip_range              | 0.2                                  |
# |    clip_range_vf           | 0.2                                  |
# |    entropy_loss            | -2.35                                |
# |    explained_variance      | 0.879                                |
# |    learning_rate           | 0.00025                              |
# |    loss                    | -0.0483                              |
# |    n_updates               | 18                                   |
# |    policy_gradient_loss    | -0.00184                             |
# |    value_loss              | 0.0054                               |
# ---------------------------------------------------------------------
# ---------------------------------------------------------------------
# | custom/                    |                                      |
# |    action_0_prob           | 0.0781                               |
# |    action_10_prob          | 0.141                                |
# |    action_1_prob           | 0.0469                               |
# |    action_2_prob           | 0.0156                               |
# |    action_3_prob           | 0.0312                               |
# |    action_4_prob           | 0.0781                               |
# |    action_5_prob           | 0.109                                |
# |    action_6_prob           | 0.141                                |
# |    action_7_prob           | 0.109                                |
# |    action_8_prob           | 0.156                                |
# |    action_9_prob           | 0.0938                               |
# |    avg_param_norm          | 1.6069782                            |
# |    gradient_norm           | 0.0788                               |
# |    gradient_norm_per_param | 0.00606                              |
# |    learning_rate           | <function create_optimized_ppo_mo... |
# |    obs_max                 | 10.0                                 |
# |    obs_mean                | 0.011250147                          |
# |    obs_min                 | -1.7288074                           |
# |    obs_std                 | 0.8288497                            |
# |    policy_first_layer_mean | -0.0060130795                        |
# |    policy_first_layer_norm | 0.6024156                            |
# |    policy_first_layer_std  | 0.037167717                          |
# |    rollout_reward_max      | 0.079486795                          |
# |    rollout_reward_mean     | -0.0085474625                        |
# |    rollout_reward_min      | -0.07940946                          |
# |    rollout_reward_std      | 0.0040345145                         |
# |    rollout_value_mean      | -3.5100708                           |
# |    rollout_value_std       | 0.2654719                            |
# |    total_policy_norm       | 10.096786                            |
# |    total_value_norm        | 10.793932                            |
# |    value_first_layer_mean  | 0.0034127985                         |
# |    value_first_layer_norm  | 0.59796435                           |
# |    value_first_layer_std   | 0.037216622                          |
# | env/                       |                                      |
# |    action_percentage       | 0.1                                  |
# |    action_pov              | 0.17                                 |
# |    arrival_cost            | 1.38e-05                             |
# |    arrival_price           | 174                                  |
# |    holding_risk_cost       | 0.000382                             |
# |    order_vwap              | 174                                  |
# |    rate_penalty            | 6.89e-05                             |
# |    shares_remaining        | 9945                                 |
# |    slippage_bps            | 19.7                                 |
# |    step_reward             | -0.000466                            |
# |    total_step_cost         | 0.000466                             |
# |    unfilled_cost           | 0                                    |
# |    vwap_cost               | 1.34e-06                             |
# | time/                      |                                      |
# |    fps                     | 3803                                 |
# |    iterations              | 8                                    |
# |    time_elapsed            | 275                                  |
# |    total_timesteps         | 1048576                              |
# | train/                     |                                      |
# |    approx_kl               | 0.0060837446                         |
# |    clip_fraction           | 0.0204                               |
# |    clip_range              | 0.2                                  |
# |    clip_range_vf           | 0.2                                  |
# |    entropy_loss            | -2.35                                |
# |    explained_variance      | 0.895                                |
# |    learning_rate           | 0.000241                             |
# |    loss                    | -0.0485                              |
# |    n_updates               | 21                                   |
# |    policy_gradient_loss    | -0.0015                              |
# |    value_loss              | 0.00514                              |
# ---------------------------------------------------------------------
# ---------------------------------------------------------------------
# | custom/                    |                                      |
# |    action_0_prob           | 0.0625                               |
# |    action_10_prob          | 0.188                                |
# |    action_1_prob           | 0.0625                               |
# |    action_2_prob           | 0.0938                               |
# |    action_3_prob           | 0.0781                               |
# |    action_4_prob           | 0.0625                               |
# |    action_5_prob           | 0.0469                               |
# |    action_6_prob           | 0.125                                |
# |    action_7_prob           | 0.109                                |
# |    action_8_prob           | 0.0469                               |
# |    action_9_prob           | 0.125                                |
# |    avg_param_norm          | 1.6128414                            |
# |    gradient_norm           | 0.0942                               |
# |    gradient_norm_per_param | 0.00724                              |
# |    learning_rate           | <function create_optimized_ppo_mo... |
# |    obs_max                 | 10.0                                 |
# |    obs_mean                | -0.018267535                         |
# |    obs_min                 | -1.7265042                           |
# |    obs_std                 | 0.6821663                            |
# |    policy_first_layer_mean | -0.0061307102                        |
# |    policy_first_layer_norm | 0.6036322                            |
# |    policy_first_layer_std  | 0.037225556                          |
# |    rollout_reward_max      | 0.039683875                          |
# |    rollout_reward_mean     | -0.00859308                          |
# |    rollout_reward_min      | -0.09247333                          |
# |    rollout_reward_std      | 0.0041126697                         |
# |    rollout_value_mean      | -3.6033547                           |
# |    rollout_value_std       | 0.25703946                           |
# |    total_policy_norm       | 10.1175785                           |
# |    total_value_norm        | 10.84936                             |
# |    value_first_layer_mean  | 0.0036661958                         |
# |    value_first_layer_norm  | 0.6003062                            |
# |    value_first_layer_std   | 0.037339587                          |
# | env/                       |                                      |
# |    action_percentage       | 1                                    |
# |    action_pov              | 0.191                                |
# |    arrival_cost            | 1.14e-06                             |
# |    arrival_price           | 196                                  |
# |    holding_risk_cost       | 0.000544                             |
# |    order_vwap              | 195                                  |
# |    rate_penalty            | 5.84e-05                             |
# |    shares_remaining        | 4534                                 |
# |    slippage_bps            | 58.3                                 |
# |    step_reward             | -0.000604                            |
# |    total_step_cost         | 0.000604                             |
# |    unfilled_cost           | 0                                    |
# |    vwap_cost               | 1.11e-07                             |
# | time/                      |                                      |
# |    fps                     | 3807                                 |
# |    iterations              | 9                                    |
# |    time_elapsed            | 309                                  |
# |    total_timesteps         | 1179648                              |
# | train/                     |                                      |
# |    approx_kl               | 0.0052445363                         |
# |    clip_fraction           | 0.0139                               |
# |    clip_range              | 0.2                                  |
# |    clip_range_vf           | 0.2                                  |
# |    entropy_loss            | -2.34                                |
# |    explained_variance      | 0.903                                |
# |    learning_rate           | 0.000233                             |
# |    loss                    | -0.0496                              |
# |    n_updates               | 24                                   |
# |    policy_gradient_loss    | -0.00124                             |
# |    value_loss              | 0.00524                              |
# ---------------------------------------------------------------------
# ---------------------------------------------------------------------
# | custom/                    |                                      |
# |    action_0_prob           | 0.0156                               |
# |    action_10_prob          | 0.172                                |
# |    action_1_prob           | 0.0625                               |
# |    action_2_prob           | 0.0781                               |
# |    action_3_prob           | 0.0938                               |
# |    action_4_prob           | 0.0625                               |
# |    action_5_prob           | 0.0312                               |
# |    action_6_prob           | 0.0781                               |
# |    action_7_prob           | 0.125                                |
# |    action_8_prob           | 0.109                                |
# |    action_9_prob           | 0.172                                |
# |    avg_param_norm          | 1.6186805                            |
# |    gradient_norm           | 0.168                                |
# |    gradient_norm_per_param | 0.0129                               |
# |    learning_rate           | <function create_optimized_ppo_mo... |
# |    obs_max                 | 10.0                                 |
# |    obs_mean                | -0.011867119                         |
# |    obs_min                 | -1.722527                            |
# |    obs_std                 | 0.75894445                           |
# |    policy_first_layer_mean | -0.0062755393                        |
# |    policy_first_layer_norm | 0.6026836                            |
# |    policy_first_layer_std  | 0.037141286                          |
# |    rollout_reward_max      | 0.043976597                          |
# |    rollout_reward_mean     | -0.008758175                         |
# |    rollout_reward_min      | -0.43478805                          |
# |    rollout_reward_std      | 0.0042547956                         |
# |    rollout_value_mean      | -3.689577                            |
# |    rollout_value_std       | 0.2453502                            |
# |    total_policy_norm       | 10.137614                            |
# |    total_value_norm        | 10.905231                            |
# |    value_first_layer_mean  | 0.0038960443                         |
# |    value_first_layer_norm  | 0.60162663                           |
# |    value_first_layer_std   | 0.03739928                           |
# | env/                       |                                      |
# |    action_percentage       | -0.5                                 |
# |    action_pov              | 0.0389                               |
# |    arrival_cost            | -0                                   |
# |    arrival_price           | 65.5                                 |
# |    holding_risk_cost       | 0.00101                              |
# |    order_vwap              | 0                                    |
# |    rate_penalty            | 7.79e-09                             |
# |    shares_remaining        | 20325                                |
# |    slippage_bps            | 1e+04                                |
# |    step_reward             | -0.00101                             |
# |    total_step_cost         | 0.00101                              |
# |    unfilled_cost           | 0                                    |
# |    vwap_cost               | 0                                    |
# | time/                      |                                      |
# |    fps                     | 3807                                 |
# |    iterations              | 10                                   |
# |    time_elapsed            | 344                                  |
# |    total_timesteps         | 1310720                              |
# | train/                     |                                      |
# |    approx_kl               | 0.0055182707                         |
# |    clip_fraction           | 0.0147                               |
# |    clip_range              | 0.2                                  |
# |    clip_range_vf           | 0.2                                  |
# |    entropy_loss            | -2.35                                |
# |    explained_variance      | 0.906                                |
# |    learning_rate           | 0.000224                             |
# |    loss                    | -0.0476                              |
# |    n_updates               | 27                                   |
# |    policy_gradient_loss    | -0.00138                             |
# |    value_loss              | 0.00498                              |
# ---------------------------------------------------------------------
# ---------------------------------------------------------------------
# | custom/                    |                                      |
# |    action_0_prob           | 0.0625                               |
# |    action_10_prob          | 0.125                                |
# |    action_1_prob           | 0.0312                               |
# |    action_2_prob           | 0.0625                               |
# |    action_3_prob           | 0.0938                               |
# |    action_4_prob           | 0.0312                               |
# |    action_5_prob           | 0.0781                               |
# |    action_6_prob           | 0.156                                |
# |    action_7_prob           | 0.125                                |
# |    action_8_prob           | 0.0938                               |
# |    action_9_prob           | 0.141                                |
# |    avg_param_norm          | 1.6246558                            |
# ...
# |    fps                     | 3823                                 |
# |    iterations              | 33                                   |
# |    time_elapsed            | 1131                                 |
# |    total_timesteps         | 4325376                              |
# | train/                     |                                      |
# |    approx_kl               | 0.0024739977                         |
# |    clip_fraction           | 0.000295                             |
# |    clip_range              | 0.2                                  |
# |    clip_range_vf           | 0.2                                  |
# |    entropy_loss            | -2.31                                |
# |    explained_variance      | 0.896                                |
# |    learning_rate           | 3.11e-05                             |
# |    loss                    | -0.0453                              |
# |    n_updates               | 96                                   |
# |    policy_gradient_loss    | -0.000571                            |
# |    value_loss              | 0.00396                              |
# ---------------------------------------------------------------------
# ---------------------------------------------------------------------
# | custom/                    |                                      |
# |    action_0_prob           | 0.0312                               |
# |    action_10_prob          | 0.125                                |
# |    action_1_prob           | 0.0312                               |
# |    action_2_prob           | 0.0312                               |
# |    action_3_prob           | 0.0625                               |
# |    action_4_prob           | 0.0312                               |
# |    action_5_prob           | 0.0469                               |
# |    action_6_prob           | 0.0938                               |
# |    action_7_prob           | 0.141                                |
# |    action_8_prob           | 0.172                                |
# |    action_9_prob           | 0.234                                |
# |    avg_param_norm          | 1.6886529                            |
# |    gradient_norm           | 0.0988                               |
# |    gradient_norm_per_param | 0.0076                               |
# |    learning_rate           | <function create_optimized_ppo_mo... |
# |    obs_max                 | 10.0                                 |
# |    obs_mean                | -0.028103057                         |
# |    obs_min                 | -1.7304795                           |
# |    obs_std                 | 0.6527968                            |
# |    policy_first_layer_mean | -0.006592444                         |
# |    policy_first_layer_norm | 0.6017935                            |
# |    policy_first_layer_std  | 0.037029844                          |
# |    rollout_reward_max      | 0.10597329                           |
# |    rollout_reward_mean     | -0.009777795                         |
# |    rollout_reward_min      | -0.055858508                         |
# |    rollout_reward_std      | 0.0047917482                         |
# |    rollout_value_mean      | -5.8092527                           |
# |    rollout_value_std       | 0.18220162                           |
# |    total_policy_norm       | 10.355771                            |
# |    total_value_norm        | 11.596717                            |
# |    value_first_layer_mean  | 0.006111415                          |
# |    value_first_layer_norm  | 0.6223387                            |
# |    value_first_layer_std   | 0.038413048                          |
# | env/                       |                                      |
# |    action_percentage       | 0.5                                  |
# |    action_pov              | 0.0487                               |
# |    arrival_cost            | 6.13e-05                             |
# |    arrival_price           | 154                                  |
# |    holding_risk_cost       | 9.52e-05                             |
# |    order_vwap              | 152                                  |
# |    rate_penalty            | 7.98e-05                             |
# |    shares_remaining        | 1911                                 |
# |    slippage_bps            | 121                                  |
# |    step_reward             | -0.000233                            |
# |    total_step_cost         | 0.000233                             |
# |    unfilled_cost           | 0                                    |
# |    vwap_cost               | -2.96e-06                            |
# | time/                      |                                      |
# |    fps                     | 3821                                 |
# |    iterations              | 34                                   |
# |    time_elapsed            | 1166                                 |
# |    total_timesteps         | 4456448                              |
# | train/                     |                                      |
# |    approx_kl               | 0.0006096416                         |
# |    clip_fraction           | 0                                    |
# |    clip_range              | 0.2                                  |
# |    clip_range_vf           | 0.2                                  |
# |    entropy_loss            | -2.32                                |
# |    explained_variance      | 0.892                                |
# |    learning_rate           | 2.27e-05                             |
# |    loss                    | -0.0449                              |
# |    n_updates               | 99                                   |
# |    policy_gradient_loss    | -0.000206                            |
# |    value_loss              | 0.00402                              |
# ---------------------------------------------------------------------
# ---------------------------------------------------------------------
# | custom/                    |                                      |
# |    action_0_prob           | 0.0156                               |
# |    action_10_prob          | 0.141                                |
# |    action_1_prob           | 0.0938                               |
# |    action_2_prob           | 0.0469                               |
# |    action_3_prob           | 0.0625                               |
# |    action_4_prob           | 0.0781                               |
# |    action_5_prob           | 0.0781                               |
# |    action_6_prob           | 0.0625                               |
# |    action_7_prob           | 0.109                                |
# |    action_8_prob           | 0.172                                |
# |    action_9_prob           | 0.141                                |
# |    avg_param_norm          | 1.6893166                            |
# |    gradient_norm           | 0.0765                               |
# |    gradient_norm_per_param | 0.00588                              |
# |    learning_rate           | <function create_optimized_ppo_mo... |
# |    obs_max                 | 10.0                                 |
# |    obs_mean                | 0.0010449481                         |
# |    obs_min                 | -1.7318614                           |
# |    obs_std                 | 0.7291764                            |
# |    policy_first_layer_mean | -0.006587236                         |
# |    policy_first_layer_norm | 0.60184866                           |
# |    policy_first_layer_std  | 0.037034273                          |
# |    rollout_reward_max      | 0.05885139                           |
# |    rollout_reward_mean     | -0.0098933475                        |
# |    rollout_reward_min      | -0.11627141                          |
# |    rollout_reward_std      | 0.0048383125                         |
# |    rollout_value_mean      | -5.882327                            |
# |    rollout_value_std       | 0.18775359                           |
# |    total_policy_norm       | 10.355649                            |
# |    total_value_norm        | 11.605467                            |
# |    value_first_layer_mean  | 0.006159961                          |
# |    value_first_layer_norm  | 0.62275827                           |
# |    value_first_layer_std   | 0.038431853                          |
# | env/                       |                                      |
# |    action_percentage       | 0.5                                  |
# |    action_pov              | 0.239                                |
# |    arrival_cost            | 3.04e-05                             |
# |    arrival_price           | 39.2                                 |
# |    holding_risk_cost       | 0.000573                             |
# |    order_vwap              | 38.8                                 |
# |    rate_penalty            | 0.000107                             |
# |    shares_remaining        | 200422                               |
# |    slippage_bps            | 107                                  |
# |    step_reward             | -0.000713                            |
# |    total_step_cost         | 0.000713                             |
# |    unfilled_cost           | 0                                    |
# |    vwap_cost               | 3.22e-06                             |
# | time/                      |                                      |
# |    fps                     | 3823                                 |
# |    iterations              | 35                                   |
# |    time_elapsed            | 1199                                 |
# |    total_timesteps         | 4587520                              |
# | train/                     |                                      |
# |    approx_kl               | 0.00017023727                        |
# |    clip_fraction           | 0                                    |
# |    clip_range              | 0.2                                  |
# |    clip_range_vf           | 0.2                                  |
# |    entropy_loss            | -2.32                                |
# |    explained_variance      | 0.897                                |
# |    learning_rate           | 1.43e-05                             |
# |    loss                    | -0.0446                              |
# |    n_updates               | 102                                  |
# |    policy_gradient_loss    | -0.000156                            |
# |    value_loss              | 0.00384                              |
# ---------------------------------------------------------------------
# ---------------------------------------------------------------------
# | custom/                    |                                      |
# |    action_0_prob           | 0.0469                               |
# |    action_10_prob          | 0.156                                |
# |    action_1_prob           | 0.0625                               |
# |    action_2_prob           | 0.0938                               |
# |    action_3_prob           | 0.0469                               |
# |    action_4_prob           | 0.0469                               |
# |    action_5_prob           | 0.125                                |
# |    action_6_prob           | 0.125                                |
# |    action_7_prob           | 0.0312                               |
# |    action_8_prob           | 0.0781                               |
# |    action_9_prob           | 0.188                                |
# |    avg_param_norm          | 1.6896842                            |
# |    gradient_norm           | 0.114                                |
# |    gradient_norm_per_param | 0.00877                              |
# |    learning_rate           | <function create_optimized_ppo_mo... |
# |    obs_max                 | 10.0                                 |
# |    obs_mean                | -0.0026142811                        |
# |    obs_min                 | -1.7308583                           |
# |    obs_std                 | 0.76449025                           |
# |    policy_first_layer_mean | -0.00658358                          |
# |    policy_first_layer_norm | 0.60186785                           |
# |    policy_first_layer_std  | 0.03703614                           |
# |    rollout_reward_max      | 0.043014098                          |
# |    rollout_reward_mean     | -0.009857063                         |
# |    rollout_reward_min      | -0.0836845                           |
# |    rollout_reward_std      | 0.0048580887                         |
# |    rollout_value_mean      | -5.9736476                           |
# |    rollout_value_std       | 0.17683448                           |
# |    total_policy_norm       | 10.355318                            |
# |    total_value_norm        | 11.610577                            |
# |    value_first_layer_mean  | 0.0061802613                         |
# |    value_first_layer_norm  | 0.623052                             |
# |    value_first_layer_std   | 0.03844719                           |
# | env/                       |                                      |
# |    action_percentage       | 0.75                                 |
# |    action_pov              | 0.156                                |
# |    arrival_cost            | -9.52e-05                            |
# |    arrival_price           | 22.6                                 |
# |    holding_risk_cost       | 5.5e-05                              |
# |    order_vwap              | 22.3                                 |
# |    rate_penalty            | 2.2e-05                              |
# |    shares_remaining        | 15856                                |
# |    slippage_bps            | 108                                  |
# |    step_reward             | 2.88e-05                             |
# |    total_step_cost         | -2.88e-05                            |
# |    unfilled_cost           | 0                                    |
# |    vwap_cost               | -1.07e-05                            |
# | time/                      |                                      |
# |    fps                     | 3823                                 |
# |    iterations              | 36                                   |
# |    time_elapsed            | 1234                                 |
# |    total_timesteps         | 4718592                              |
# | train/                     |                                      |
# |    approx_kl               | 5.602122e-05                         |
# |    clip_fraction           | 0                                    |
# |    clip_range              | 0.2                                  |
# |    clip_range_vf           | 0.2                                  |
# |    entropy_loss            | -2.32                                |
# |    explained_variance      | 0.9                                  |
# |    learning_rate           | 5.93e-06                             |
# |    loss                    | -0.0451                              |
# |    n_updates               | 105                                  |
# |    policy_gradient_loss    | -0.0001                              |
# |    value_loss              | 0.00406                              |
# ---------------------------------------------------------------------
# 2025-08-28 21:18:39 - root - INFO -
# ============================================================
# 2025-08-28 21:18:39 - root - INFO - TRAINING COMPLETED: ppo_cnn_multiorder_exec_vec_cpu
# 2025-08-28 21:18:39 - root - INFO - ============================================================
# 2025-08-28 21:18:39 - root - INFO -   Total training time: 1236.13 seconds
# 2025-08-28 21:18:39 - root - INFO -   Total timesteps: 4,680,000.0
# 2025-08-28 21:18:39 - root - INFO -   Performance: 3786.0 steps/second
# 2025-08-28 21:18:39 - root - INFO -   Time per 1000 steps: 0.26 seconds
# 2025-08-28 21:18:39 - root - INFO -   Expected remaining time for 1M steps: -16.2 minutes
# (<stable_baselines3.ppo.ppo.PPO at 0x70e4bacb6450>, 1236.1303322315216)

# %%
import map_elites_models as mem
import optimal_execution_env_vectorized as oeev
importlib.reload(mem)
importlib.reload(oeev)
import map_elites_models as mem
import optimal_execution_env_vectorized as oeev

mem_train_execution_cpu_env = oeev.VectorizedMultiOrderExecutionEnv(
    stock_df_list=train_stock_df_list,
    orders_df=train_orders_df,
    impact_coef=1,
    decay_rate=5,
    num_envs=128,  
    min_rate=0,
    max_rate=max_trading_rate,
    device='cpu',
    seed=fixed_seed,
    cost_model=rl_cost_model
)


archive = mem.map_elites(
    train_execution_cpu_env,
    init_policies=256,          # 128–256 sweet spot
    iters=60,                   # 30–60 if you’ve got time
    eval_orders_per_policy=5,   # 3 for speed, 5 for stability
    mutate_sigma=0.04,
    device="cpu",
    show_progress=False
)
# Out:
# 2025-08-28 21:18:39 - optimal_execution_env_vectorized - INFO - Using device: cpu (explicitly set)
# MAP-Elites: seeding:  24%|██▍       | 62/256 [01:18<04:45,  1.47s/it]
# 2025-08-28 21:20:01 - optimal_execution_env_vectorized - WARNING - Found 60 NaN or non-positive Y values, replacing with median 5.261182450626857e-05
# MAP-Elites: seeding:  25%|██▍       | 63/256 [01:20<04:21,  1.35s/it]
# 2025-08-28 21:20:02 - optimal_execution_env_vectorized - WARNING - Found 60 NaN or non-positive Y values, replacing with median 8.996471830535757e-05
# MAP-Elites: seeding:  58%|█████▊    | 149/256 [03:03<02:52,  1.61s/it]
# 2025-08-28 21:21:46 - optimal_execution_env_vectorized - WARNING - Found 1 NaN or non-positive Y values, replacing with median 2.4517733114283492e-05
# MAP-Elites: seeding:  94%|█████████▍| 241/256 [04:58<00:14,  1.04it/s]
# 2025-08-28 21:23:41 - optimal_execution_env_vectorized - WARNING - Found 1 NaN or non-positive Y values, replacing with median 4.480050113884786e-05
# MAP-Elites: seeding: 100%|██████████| 256/256 [05:16<00:00,  1.24s/it]
# MAP-Elites: iterations:   3%|▎         | 2/60 [00:28<13:56, 14.42s/it]
# 2025-08-28 21:24:33 - optimal_execution_env_vectorized - WARNING - Found 1 NaN or non-positive Y values, replacing with median 4.874158875316903e-05
# MAP-Elites: iterations:   5%|▌         | 3/60 [00:45<14:44, 15.52s/it]
# 2025-08-28 21:24:59 - optimal_execution_env_vectorized - WARNING - Found 60 NaN or non-positive Y values, replacing with median 3.072624364568081e-05
# MAP-Elites: iterations:  23%|██▎       | 14/60 [03:53<13:27, 17.54s/it]
# 2025-08-28 21:28:05 - optimal_execution_env_vectorized - WARNING - Found 1 NaN or non-positive Y values, replacing with median 4.154954299024492e-05
# MAP-Elites: iterations:  28%|██▊       | 17/60 [04:52<13:34, 18.94s/it]
# 2025-08-28 21:28:53 - optimal_execution_env_vectorized - WARNING - Found 1 NaN or non-positive Y values, replacing with median 3.982779983758338e-05
# 2025-08-28 21:29:00 - optimal_execution_env_vectorized - WARNING - Found 1 NaN or non-positive Y values, replacing with median 3.6085471935000035e-05
# MAP-Elites: iterations:  30%|███       | 18/60 [05:14<13:49, 19.76s/it]
# 2025-08-28 21:29:18 - optimal_execution_env_vectorized - WARNING - Found 1 NaN or non-positive Y values, replacing with median 2.854392003517419e-05
# MAP-Elites: iterations:  35%|███▌      | 21/60 [06:15<13:05, 20.14s/it]
# 2025-08-28 21:30:30 - optimal_execution_env_vectorized - WARNING - Found 1 NaN or non-positive Y values, replacing with median 2.9802832397836054e-05
# MAP-Elites: iterations:  38%|███▊      | 23/60 [06:54<12:01, 19.50s/it]
# 2025-08-28 21:31:04 - optimal_execution_env_vectorized - WARNING - Found 1 NaN or non-positive Y values, replacing with median 2.248601118895833e-05
# MAP-Elites: iterations:  40%|████      | 24/60 [07:13<11:45, 19.61s/it]
# 2025-08-28 21:31:28 - optimal_execution_env_vectorized - WARNING - Found 1 NaN or non-positive Y values, replacing with median 1.9925307318081495e-05
# MAP-Elites: iterations:  63%|██████▎   | 38/60 [12:14<08:09, 22.23s/it]
# 2025-08-28 21:36:16 - optimal_execution_env_vectorized - WARNING - Found 1 NaN or non-positive Y values, replacing with median 3.178542605520224e-05
# 2025-08-28 21:36:23 - optimal_execution_env_vectorized - WARNING - Found 60 NaN or non-positive Y values, replacing with median 3.569528800767631e-05
# MAP-Elites: iterations:  65%|██████▌   | 39/60 [12:39<08:05, 23.14s/it]
# 2025-08-28 21:36:42 - optimal_execution_env_vectorized - WARNING - Found 1 NaN or non-positive Y values, replacing with median 4.2828477399615666e-05
# MAP-Elites: iterations:  67%|██████▋   | 40/60 [13:01<07:30, 22.54s/it]
# 2025-08-28 21:37:02 - optimal_execution_env_vectorized - WARNING - Found 1 NaN or non-positive Y values, replacing with median 2.7038117646879547e-05
# MAP-Elites: iterations:  68%|██████▊   | 41/60 [13:24<07:15, 22.93s/it]
# 2025-08-28 21:37:35 - optimal_execution_env_vectorized - WARNING - Found 1 NaN or non-positive Y values, replacing with median 2.6352194684724865e-05
# MAP-Elites: iterations:  70%|███████   | 42/60 [13:46<06:47, 22.62s/it]
# 2025-08-28 21:38:06 - optimal_execution_env_vectorized - WARNING - Found 1 NaN or non-positive Y values, replacing with median 4.127271841653619e-05
# MAP-Elites: iterations:  75%|███████▌  | 45/60 [14:55<05:39, 22.62s/it]
# 2025-08-28 21:39:09 - optimal_execution_env_vectorized - WARNING - Found 60 NaN or non-positive Y values, replacing with median 2.911986789102969e-05
# MAP-Elites: iterations:  78%|███████▊  | 47/60 [15:40<04:53, 22.58s/it]
# 2025-08-28 21:40:03 - optimal_execution_env_vectorized - WARNING - Found 1 NaN or non-positive Y values, replacing with median 4.0517154759229966e-05
# MAP-Elites: iterations:  83%|████████▎ | 50/60 [16:58<04:08, 24.81s/it]
# 2025-08-28 21:41:21 - optimal_execution_env_vectorized - WARNING - Found 1 NaN or non-positive Y values, replacing with median 0.00016998273614769017
# MAP-Elites: iterations: 100%|██████████| 60/60 [21:33<00:00, 21.56s/it]

# %%
best = archive.best()
print("Best fitness:", best["fitness"], "desc:", best["desc"])  

# Test the elite policy
elite_policy = best["policy"]
num_test_orders = 5000   
test_idxs = mem_train_execution_cpu_env.generate_random_order_indices(num_test_orders)
orders = mem_train_execution_cpu_env.execute_orders_vectorized(elite_policy, test_idxs, collect_step_info=True)
print(f"Mean total cost ({num_test_orders} orders):", np.mean([
    sum([s.get("total_step_cost", 0.0) for s in tr]) if any("total_step_cost" in s for s in tr) else tr[-1].get("total_cost", 0.0)
    for tr in orders if tr
]))
# Out:
# Best fitness: -0.009804063521005445 desc: (1.0, 0.8049563419754484)
#   Executing 5000 orders:  10%|█         | 512/5000 orders [00:31<05:04]
# 2025-08-28 21:46:04 - optimal_execution_env_vectorized - WARNING - Found 1 NaN or non-positive Y values, replacing with median 3.070410681689021e-05
# 2025-08-28 21:46:04 - optimal_execution_env_vectorized - WARNING - Found 1 NaN or non-positive tau values, replacing with median 48.53804924083881
#   Executing 5000 orders:  13%|█▎        | 640/5000 orders [00:40<05:01]
# 2025-08-28 21:46:13 - optimal_execution_env_vectorized - WARNING - Found 1 NaN or non-positive Y values, replacing with median 3.208542884938155e-05
#   Executing 5000 orders:  26%|██▌       | 1280/5000 orders [01:31<04:54]
# 2025-08-28 21:47:04 - optimal_execution_env_vectorized - WARNING - Found 1 NaN or non-positive Y values, replacing with median 3.3902476995014615e-05
#   Executing 5000 orders:  33%|███▎      | 1664/5000 orders [02:00<04:15]
# 2025-08-28 21:47:33 - optimal_execution_env_vectorized - WARNING - Found 1 NaN or non-positive Y values, replacing with median 3.642075278864184e-05
#   Executing 5000 orders:  38%|███▊      | 1920/5000 orders [02:21<04:02]
# 2025-08-28 21:47:54 - optimal_execution_env_vectorized - WARNING - Found 1 NaN or non-positive Y values, replacing with median 3.2042986005752194e-05
#   Executing 5000 orders:  41%|████      | 2048/5000 orders [02:31<03:49]
# 2025-08-28 21:48:04 - optimal_execution_env_vectorized - WARNING - Found 1 NaN or non-positive Y values, replacing with median 3.194137507942856e-05
#   Executing 5000 orders:  46%|████▌     | 2304/5000 orders [02:52<03:34]
# 2025-08-28 21:48:25 - optimal_execution_env_vectorized - WARNING - Found 1 NaN or non-positive Y values, replacing with median 3.2554501681118144e-05
#   Executing 5000 orders:  49%|████▊     | 2432/5000 orders [03:01<03:21]
# 2025-08-28 21:48:34 - optimal_execution_env_vectorized - WARNING - Found 1 NaN or non-positive Y values, replacing with median 3.093283818217257e-05
#   Executing 5000 orders:  54%|█████▍    | 2688/5000 orders [03:22<03:02]
# 2025-08-28 21:48:55 - optimal_execution_env_vectorized - WARNING - Found 2 NaN or non-positive Y values, replacing with median 3.309915338710657e-05
#   Executing 5000 orders:  59%|█████▉    | 2944/5000 orders [03:41<02:37]
# 2025-08-28 21:49:14 - optimal_execution_env_vectorized - WARNING - Found 1 NaN or non-positive Y values, replacing with median 3.4238094991179405e-05
#   Executing 5000 orders:  84%|████████▍ | 4224/5000 orders [05:23<01:01]
# 2025-08-28 21:50:56 - optimal_execution_env_vectorized - WARNING - Found 1 NaN or non-positive Y values, replacing with median 3.506514025739919e-05
#   Executing 5000 orders: 100%|█████████▉| 4992/5000 orders [06:26<00:00]
# 2025-08-28 21:51:59 - optimal_execution_env_vectorized - WARNING - Found 1 NaN or non-positive Y values, replacing with median 3.106446074220633e-05
# Mean total cost (5000 orders): 0.039716086438503696

# %%
import optimal_execution_env_vectorized as oeev
importlib.reload(mem)
importlib.reload(oeev)
import map_elites_models as mem
import optimal_execution_env_vectorized as oeev
from map_elites_models import plot_archive_heatmap, select_elites

plot_archive_heatmap(archive)
best_overall = archive.best()
top_vwapish = select_elites(archive, finish_range=(0.45, 0.55), smooth_range=(0.7, 1.0), top_k=3)
top_front = select_elites(archive, finish_range=(0.0, 0.40), smooth_range=(0.6, 1.0), top_k=3)

# %%
from tqdm import tqdm

import cost_models as cm
importlib.reload(cm)
import cost_models as cm

test_execution_cpu_env = oeev.VectorizedMultiOrderExecutionEnv(
    stock_df_list=test_stock_df_list,
    orders_df=test_orders_df,
    impact_coef=1,
    decay_rate=5,
    num_envs=num_vec_envs_cpu_test,  
    min_rate=0,
    max_rate=max_trading_rate,
    device='cpu',
    seed=fixed_seed,
    cost_model=rl_cost_model
)

print("OK: Vectorized cpu test environment loaded!")

if device in ["cuda", "mps"]:

    print("OK: VectorizedMultiOrderExecutionEnv with training wrapper for GPU for training loaded!")

    # Create vectorized execution environments for testing (direct access for execution)
    print("\nCreating vectorized gpu test environment...")
 
    test_execution_gpu_env = oeev.VectorizedMultiOrderExecutionEnv(
        stock_df_list=test_stock_df_list,
        orders_df=test_orders_df,
        impact_coef=1,
        decay_rate=5,
        num_envs=num_vec_envs_gpu,  
        min_rate=0,
        max_rate=max_trading_rate,
        device=device,
        seed=fixed_seed
    )
    
    print("OK: Vectorized gpu test environment check loaded!")

else:
    print("No GPU available, using CPU for training and testing")
    train_execution_gpu_env = train_execution_cpu_env
    test_execution_gpu_env = test_execution_cpu_env



print("="*80)
print("All models will execute the same orders")
print("="*80)

model_name_list = mp_vec.list_models()
print(f"Available models: {model_name_list}")

num_episodes = 7500  
execution_times = {}
test_orders = {}

print(f"All {len(model_name_list)} models will execute the same {num_episodes} orders for fair comparison.")
print("="*80)

# Manual consistent comparison approach
common_order_indices = None
i = 0

base_cpu_env = test_execution_cpu_env.venv if isinstance(test_execution_cpu_env, VecNormalize) else test_execution_cpu_env
common_order_indices = base_cpu_env.generate_random_order_indices(num_episodes) 
print(f"Using order indices: {common_order_indices[:5]}...{common_order_indices[-5:]} (showing first/last 5)")

# support with tqdm 
for i, model_name in enumerate(tqdm(model_name_list, desc="Executing models", leave=False)):

    model = mp_vec.get_model(model_name)
    
    # if device attribute exists and is in ["cuda", "mps"] then use the gpu environment
    # otherwise use the cpu environment
    if model_name in baseline_strategies:
        eval_execution_env = test_execution_cpu_env
        model.device = "cpu"
    else:
        if hasattr(model, 'device') and model.device in ["cuda", "mps"]:
            print(f"Using GPU environment for {model_name}")
            eval_execution_env = mp_vec.load_vecnorm(model_name, test_execution_gpu_env)
        else:
            print(f"Using CPU environment for {model_name}")
            # filter out baseline strategies
            eval_execution_env = mp_vec.load_vecnorm(model_name, test_execution_cpu_env)
            model.device = "cpu"

    print(f"\n{'='*60}")
    print(f"Executing orders with model: {model_name} with device: {model.device} ({i+1}/{len(model_name_list)})")
    print(f"{'='*60}")
    
    start_time = time.time()
    
    env_for_exec = eval_execution_env.venv if isinstance(eval_execution_env, VecNormalize) else eval_execution_env
    
    if isinstance(eval_execution_env, VecNormalize):
        eval_execution_env.training = False
        eval_execution_env.norm_reward = False
    
    orders = env_for_exec.execute_orders_vectorized(
        model=model,
        order_indices=common_order_indices,
        collect_step_info=True, 
        show_progress=True,
        
        )
    
    test_orders[model_name] = orders
    
    exec_time = time.time() - start_time
    execution_times[model_name] = exec_time
    
    print(f"Execution completed in {exec_time:.2f} seconds")
    print(f"Average time per episode: {exec_time/num_episodes:.3f} seconds")
    
    # Memory cleanup between models
    if hasattr(model, 'device') and model.device in ["cuda", "mps"]:
        if test_execution_env.device == 'cuda':
            torch.cuda.empty_cache()
        gc.collect()


print(f"\nEXECUTION COMPLETED!")
if common_order_indices is not None:
    print(f"All {len(model_name_list)} models executed the same {len(common_order_indices)} orders for fair comparison!")
    print(f"Order indices used: {common_order_indices}")
else:
    print("Using fallback method - orders may not be identical across models.")
    print("Consider checking the implementation of execute_orders method.")

print(f"\n{'='*60}")
print("VECTORIZED EXECUTION SUMMARY")
print(f"{'='*60}")
total_time = sum(execution_times.values())
for model_name, exec_time in execution_times.items():
    print(f"{model_name:30}: {exec_time:6.2f}s ({exec_time/num_episodes:.3f}s/episode)")
print(f"{'Total execution time':30}: {total_time:6.2f}s")
print(f"{'Average per model':30}: {total_time/len(execution_times):6.2f}s")
# Out:
# OK: Vectorized cpu test environment loaded!
# OK: VectorizedMultiOrderExecutionEnv with training wrapper for GPU for training loaded!
#
# Creating vectorized gpu test environment...
# OK: Vectorized gpu test environment check loaded!
# ================================================================================
# All models will execute the same orders
# ================================================================================
# Available models: ['ppo_multiorder_exec_vec_nsteps_2048_batchsize_8192_epochs_3', 'vwap_baseline_vec', 'random_baseline_vec', 'ppo_cnn_multiorder_exec_vec_cpu_nsteps_2048_batchsize_8192_epochs_3']
# All 4 models will execute the same 7500 orders for fair comparison.
# ================================================================================
# Using order indices: [970, 6279, 1859, 6803, 6305]...[5191, 5226, 5390, 860, 7270] (showing first/last 5)
# Executing models:   0%|          | 0/4 [00:00<?, ?it/s]
# Using CPU environment for ppo_multiorder_exec_vec_nsteps_2048_batchsize_8192_epochs_3
#
# ============================================================
# Executing orders with model: ppo_multiorder_exec_vec_nsteps_2048_batchsize_8192_epochs_3 with device: cpu (1/4)
# ============================================================
# 2025-08-28 23:03:28 - optimal_execution_env_vectorized - WARNING - Found 5 NaN or non-positive Y values, replacing with median 3.146915980885377e-05
# 2025-08-28 23:03:28 - optimal_execution_env_vectorized - WARNING - Found 5 NaN or non-positive tau values, replacing with median 58.28370431949938
# 2025-08-28 23:04:20 - optimal_execution_env_vectorized - WARNING - Found 7 NaN or non-positive Y values, replacing with median 3.189080997737358e-05
# 2025-08-28 23:05:15 - optimal_execution_env_vectorized - WARNING - Found 7 NaN or non-positive Y values, replacing with median 3.183311766857277e-05
# 2025-08-28 23:06:07 - optimal_execution_env_vectorized - WARNING - Found 4 NaN or non-positive Y values, replacing with median 3.062708172581514e-05
# 2025-08-28 23:07:03 - optimal_execution_env_vectorized - WARNING - Found 7 NaN or non-positive Y values, replacing with median 3.090020363491152e-05

# %%
# store all tca for future recovery

import tca_data_manager as tca

tcadm = tca.TCADataManager()
tcadm.save_orders(test_orders)
# Out:
# Saved 7500 orders to: tca_data/tca_data_20250828_223104.parquet
# PosixPath('tca_data/tca_data_20250828_223104.parquet')

# %%
stored_test_orders = tcadm.load_latest()
importlib.reload(rp)
import render_plots as rp

# Vectorized plotting and analysis
print("Generating vectorized analysis...")
start_time = time.time()

# Create comprehensive summary tables
print("\nVectorized Test Environment Results:")
print("="*80)
rp.create_execution_summary_table(orders_dict=stored_test_orders, trim=0.01)
rp.plot_arrival_slippage_by_factors(orders_dict=stored_test_orders)
rp.plot_action_boxplots_by_normalized_horizon(stored_test_orders)


# Plot execution results
rp.plot_orders(stored_test_orders, num_orders=3)


analysis_time = time.time() - start_time
print(f"\nAnalysis completed in {analysis_time:.2f} seconds")

# Performance comparison and system metrics
print("\nVECTORIZED PERFORMANCE SUMMARY")
print("="*80)

# Calculate performance metrics
total_episodes = len(model_name_list) * num_episodes
total_execution_time = sum(execution_times.values())
avg_time_per_episode = total_execution_time / total_episodes

print(f"Device used: {device}")
print(f"Total models tested: {len(model_name_list)}")
print(f"Episodes per model: {num_episodes}")
print(f"Total episodes executed: {total_episodes}")
print(f"Total execution time: {total_execution_time:.2f} seconds")
print(f"Average time per episode: {avg_time_per_episode:.4f} seconds")
print(f"Episodes per second: {1/avg_time_per_episode:.2f}")

# Memory usage
memory_info = psutil.virtual_memory()
print(f"\nMemory usage:")
print(f"  Total RAM: {memory_info.total / 1e9:.1f} GB")
print(f"  Available RAM: {memory_info.available / 1e9:.1f} GB")
print(f"  Used RAM: {memory_info.used / 1e9:.1f} GB ({memory_info.percent:.1f}%)")

# GPU memory if available
if device == 'cuda':
    gpu_memory = torch.cuda.memory_allocated() / 1e9
    gpu_memory_cached = torch.cuda.memory_reserved() / 1e9
    print(f"\nGPU memory usage:")
    print(f"  Allocated: {gpu_memory:.2f} GB")
    print(f"  Cached: {gpu_memory_cached:.2f} GB")
# Out:
# Generating vectorized analysis...
#
# Vectorized Test Environment Results:
# ================================================================================
#
# Execution Summary Table
# ===================================================================================================================================================================================================================================
# Slippage trimmed (top/bottom 1.0% by notional weight)
# -----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Agent                      Count|Notional (M)|  Trim Count|Trim Not (M)|Slippage (bps)|Slippage SE (bps)|Duration Ratio| Duration SE|Return (bps)|Return SE (bps)|Reward (bps)|Reward SE (bps)|    Action %| Action SE %|Incomplete %|No Arrival %|
# -----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# ppo_multiorder_exe          7500     30591.9          54       307.1    -3067.56       42.52       0.987       0.001       -1.65        2.33     1165.56        8.03       14.91        0.09       67.00        0.00
# vwap_baseline_vec           7500     30730.8          53       309.9    -5905.28       59.92       0.988       0.001       -1.58        2.33     1254.66        8.75        0.00        0.00       66.57        0.00
# random_baseline_ve          7500     30333.6          97       603.7       -4.10       19.61       0.987       0.001       -0.16        2.33     1260.81        8.76       -0.05        0.08       66.83        0.00
# ppo_cnn_multiorder          7500     30719.3          54       313.6    -5432.83       61.15       0.987       0.001       -1.54        2.34     1160.98        7.99       15.79        0.08       67.01        0.00
# ===================================================================================================================================================================================================================================
# Note: Slippage, Returns, and Rewards are in basis points (bps)
#       SE = Standard Error (std/√n)
#       Duration Ratio is completion time / total horizon
#       Action percentages are in %
#       Incomplete % shows orders not fully executed
#       No Arrival % shows orders without arrival price data
# === Plotting orders for ppo_multiorder_exec_vec_nsteps_2048_batchsize_8192_epochs_3 ===
# === Plotting orders for vwap_baseline_vec ===
# === Plotting orders for random_baseline_vec ===
# === Plotting orders for ppo_cnn_multiorder_exec_vec_cpu_nsteps_2048_batchsize_8192_epochs_3 ===
# Analysis completed in 8.86 seconds
#
# VECTORIZED PERFORMANCE SUMMARY
# ================================================================================
# Device used: cuda
# Total models tested: 4
# Episodes per model: 7500
# Total episodes executed: 30000
# Total execution time: 2328.75 seconds
# Average time per episode: 0.0776 seconds
# Episodes per second: 12.88
#
# Memory usage:
#   Total RAM: 33.5 GB
#   Available RAM: 3.0 GB
#   Used RAM: 29.9 GB (91.1%)
#
# GPU memory usage:
#   Allocated: 1.71 GB
#   Cached: 1.74 GB

# %% [markdown]
# To-dos:
#
#
# Comparison and metric:
# * Change table to put std on a separate row
# * Fix VWAP baseline to use volume profile and execute the full horizon
# * Add Almgren-Chriss baseline
# * Normalize behaviors across agents, trajectories - actions, price sensitivity
# * Create a plot of all statistics across orders (execution statistics)
# * add trimming to the rendering function
#
# Training variablility:
# * Find and break out days by different regimes, e.g. high volatility, low volatility, trending, mean reverting, shocks, stable markets, etc. add these to the gym
#
#
# -------------------------------------------------------------------
# * Consider more advanced propagator models such as the 6-event propagator model (ch. 14 of Trades, Quotes and Prices)
# * Implement multiple agents from papers and using Quality Diveristy and MAP methods
# * Linear versus square root for 1 minute impact?
#
# * Make volume profiles to scale volume and remove auctions, remove special days
# * TODO: fix warnings in generate orders
# * TODO: refactor optimal execuion env

# %% [markdown]
# **Future Vectorized Optimizations**
#
# To-dos for enhanced vectorized performance:
#
# **Environment Optimizations:**
# * Implement true multi-GPU support for larger scale training
# * Add mixed precision training for faster convergence
# * Implement gradient accumulation for larger effective batch sizes
# * Add distributed training support
#
# **Model Optimizations:**
# * Implement model quantization for faster inference
# * Add model pruning for memory efficiency
# * Explore transformer-based architectures
# * Implement ensemble methods with vectorized prediction
#
# **Data Pipeline Optimizations:**
# * Implement data streaming for larger datasets
# * Add data preprocessing on GPU
# * Implement efficient data caching
# * Add real-time data integration
#
# **Analysis Optimizations:**
# * Vectorized metric computation
# * GPU-accelerated visualization
# * Parallel backtesting framework
# * Real-time performance monitoring
#
# The vectorized implementation demonstrates significant performance gains while maintaining the same core functionality and research objectives.
